# %%
from parameters_lstm import *

from preprocess_datapoints_lstm import *
from preprocess_text_to_tensors_lstm import *
from domain_classifier_model_lstm import *
from meter import *

import torch
from torch.autograd import Variable
import numpy
import time

saved_model_name_lstm = 'lstm_domain_adapt_explore'
saved_model_name_nn = 'lstm_nn_domain_adapt_explore'


# Initialize the data sets
processed_corpus = process_whole_corpuses()
word_to_id_vocab = processed_corpus['word_to_id']
word2vec = load_glove_embeddings(glove_path, word_to_id_vocab)
ubuntu_id_to_data_title = processed_corpus['ubuntu_id_to_data_title']
android_id_to_data_title = processed_corpus['android_id_to_data_title']
ubuntu_id_to_data_body = processed_corpus['ubuntu_id_to_data_body']
android_id_to_data_body = processed_corpus['android_id_to_data_body']


''' Data Sets '''
training_data_ubuntu = ubuntu_id_to_similar_different()
training_question_ids_ubuntu = list(training_data_ubuntu.keys())

np.random.seed(1)
data_android = android_id_to_similar_different(dev=True)
all_dev_question_ids_android = list(data_android.keys())
training_question_ids_android = all_dev_question_ids_android[:500]
dev_question_ids_android = all_dev_question_ids_android[500:]
    
test_data_android = android_id_to_similar_different(dev=False)
test_question_ids_android = list(test_data_android.keys())
# Note: Remember to edit batch_size accordingly if testing on smaller size data sets

# %%
def eval_model(lstm, ids, data, word2vec, id2Data_title, id2Data_body, word_to_id_vocab, truncation_val_title, truncation_val_body):
    lstm.eval()
    auc_scorer.reset()

    candidate_ids, q_main_ids, labels = organize_test_ids(ids, data)
    num_q_main = len(q_main_ids)
    len_pieces = round(num_q_main/50)
    print(num_q_main)

    for i in range(0, num_q_main, len_pieces):
        print(i, end = ' ')
        q_main_id_num_repl_tuple = q_main_ids[i:i+len_pieces]
        candidates = candidate_ids[i:i+len_pieces]
        current_labels = torch.from_numpy(np.array(labels[i:i+len_pieces])).long()

        candidates_qs_matrix = construct_qs_matrix_testing(candidates, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        word_to_id_vocab, truncation_val_title, truncation_val_body, main=False)
        main_qs_matrix = construct_qs_matrix_testing(q_main_id_num_repl_tuple, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        word_to_id_vocab, truncation_val_title, truncation_val_body, main=True)

        similarity_matrix_this_batch = torch.nn.functional.cosine_similarity(candidates_qs_matrix, main_qs_matrix, eps=1e-08).data
        auc_scorer.add(similarity_matrix_this_batch, current_labels)

    auc_score = auc_scorer.value()

    return auc_score

# %%
''' Params Dashboard '''

''' Procedural parameters '''
batch_size = 40
num_differing_questions = 20
num_epochs = 2


''' Model specs LSTM '''
dropout = 0.3
margin = 0.1
lr_lstm = 10**-3

input_size = 300
hidden_size = 240
num_layers = 1
bias = True
batch_first = True
bidirectional = True
first_dim = num_layers * 2 if bidirectional else num_layers


''' Model specs NN '''
lr_nn = -10**-3
lamb = 10**-6

input_size_nn = 2*hidden_size if bidirectional else hidden_size
first_hidden_size_nn = 300
second_hidden_size_nn = 150


''' Data processing specs '''
truncation_val_title = 15
truncation_val_body = 85
padding_idx = 0

glove_path = '../glove.840B.300d.txt'
android_corpus_path = '../android_dataset/corpus.tsv'
ubuntu_corpus_path = '../ubuntu_dataset/text_tokenized.txt'

# %%
''' Encoder (LSTM) '''
lstm = torch.nn.LSTM(input_size, hidden_size, num_layers, bias, batch_first, dropout, bidirectional)
loss_function_lstm = torch.nn.MultiMarginLoss(margin=margin)
optimizer_lstm = torch.optim.Adam(lstm.parameters(), lr=lr_lstm)

h0 = Variable(torch.zeros(first_dim, 1, hidden_size), requires_grad=False)
c0 = Variable(torch.zeros(first_dim, 1, hidden_size), requires_grad=False)


''' Domain Classifier (Neural Net) '''
neural_net = DomainClassifier(input_size_nn, first_hidden_size_nn, second_hidden_size_nn)
loss_function_nn = nn.CrossEntropyLoss()
optimizer_nn = torch.optim.Adam(neural_net.parameters(), lr=lr_nn)

''' Procedural parameters '''
num_batches = round(len(training_question_ids_ubuntu) / batch_size)
auc_scorer = AUCMeter()


def train_lstm_question_similarity(lstm, batch_ids_ubuntu, batch_ids_android, batch_data_ubuntu, batch_data_android, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body,\
                                   android_id_to_data_title, android_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body):
    lstm.train()
    sequence_ids_ubuntu, dict_sequence_lengths_ubuntu = organize_ids_training(batch_ids_ubuntu, batch_data_ubuntu, num_differing_questions)
    sequence_ids_android, dict_sequence_lengths_android = organize_ids_training(batch_ids_android, batch_data_android, num_differing_questions)
    
    candidates_qs_tuples_matrix_ubuntu = construct_qs_matrix_training(sequence_ids_ubuntu, lstm, h0, c0, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body,
        dict_sequence_lengths_ubuntu, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=True)
    
    candidates_qs_tuples_matrix_android = construct_qs_matrix_training(sequence_ids_android, lstm, h0, c0, word2vec, android_id_to_data_title, android_id_to_data_body,
        dict_sequence_lengths_android, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=True)
    
    main_qs_tuples_matrix_ubuntu = construct_qs_matrix_training(batch_ids_ubuntu, lstm, h0, c0, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body,
        dict_sequence_lengths_ubuntu, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=False)
    
    main_qs_tuples_matrix_android = construct_qs_matrix_training(batch_ids_android, lstm, h0, c0, word2vec, android_id_to_data_title, android_id_to_data_body,
        dict_sequence_lengths_android, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=False)
        
    similarity_matrix_ubuntu = torch.nn.functional.cosine_similarity(candidates_qs_tuples_matrix_ubuntu, main_qs_tuples_matrix_ubuntu, dim=2, eps=1e-6)
    target_ubuntu = Variable(torch.LongTensor([0] * int(len(sequence_ids_ubuntu) / (1 + num_differing_questions))))
    
    similarity_matrix_android = torch.nn.functional.cosine_similarity(candidates_qs_tuples_matrix_android, main_qs_tuples_matrix_android, dim=2, eps=1e-6)
    target_android = Variable(torch.LongTensor([0] * int(len(sequence_ids_android) / (1 + num_differing_questions))))
    
    loss_batch = (loss_function_lstm(similarity_matrix_ubuntu, target_ubuntu) + loss_function_lstm(similarity_matrix_android, target_android))/2

    print("lstm multi-margin loss on batch:", loss_batch.data[0])
    return loss_batch


def train_nn_domain_classification(neural_net, lstm, h0, c0, ids_ubuntu, ids_android, word2vec,
    ubuntu_id_to_data_title, ubuntu_id_to_data_body, android_id_to_data_title, android_id_to_data_body, truncation_val_title, truncation_val_body):
    neural_net.train()
    lstm.train()

    qs_matrix_ubuntu = construct_qs_matrix_domain_classification(ids_ubuntu, lstm, h0, c0, word2vec,
        ubuntu_id_to_data_title, ubuntu_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body)
    qs_matrix_android = construct_qs_matrix_domain_classification(ids_android, lstm, h0, c0, word2vec,
        android_id_to_data_title, android_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body)
    overall_qs_matrix = torch.cat([qs_matrix_ubuntu, qs_matrix_android])

    out = neural_net.forward(overall_qs_matrix)
    target_vector = Variable(torch.LongTensor(torch.cat([torch.zeros(20).long(), torch.ones(20).long()])))
    loss_batch = loss_function_nn(out, target_vector)

    print("Neural net cross-entropy loss on batch:", loss_batch.data[0])
    return loss_batch

    
'''Begin training'''
for epoch in range(num_epochs):
    # Train on whole training data set
    for batch in range(1, num_batches + 1):
        if batch == 93 or batch == 301 or batch == 243:
            continue

        start = time.time()
        optimizer_lstm.zero_grad()
        optimizer_nn.zero_grad()
        print("Working on batch #: ", batch)

        # Train on ubuntu similar question retrieval
        ids_this_batch_for_lstm_ubuntu = training_question_ids_ubuntu[batch_size * (batch - 1):batch_size * batch]
        ids_this_batch_for_lstm_android = np.array(training_question_ids_android)[np.random.choice(np.arange(len(training_question_ids_android)), size = round(batch_size/6), replace = False)]
        loss_batch_similarity = train_lstm_question_similarity(lstm, ids_this_batch_for_lstm_ubuntu, ids_this_batch_for_lstm_android,
        training_data_ubuntu, data_android, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body, android_id_to_data_title, android_id_to_data_body, word_to_id_vocab,
                                                               truncation_val_title, truncation_val_body)

        # Train on ubuntu-android domain classification task
        ids_randomized_ubuntu = get_20_random_ids(training_question_ids_ubuntu)
        ids_randomized_android = get_20_random_ids(training_question_ids_android)
        loss_batch_domain_classification = train_nn_domain_classification(neural_net, lstm, h0, c0,
            ids_randomized_ubuntu, ids_randomized_android, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body, android_id_to_data_title, android_id_to_data_body,
                                                                         truncation_val_title, truncation_val_body)

        # Overall loss = multi-margin loss - LAMBDA * cross entropy loss
        overall_loss = loss_batch_similarity - (lamb * loss_batch_domain_classification)
        overall_loss.backward()
        optimizer_lstm.step()
        optimizer_nn.step()

        print("Time_on_batch:", time.time() - start)
        
        if batch % 100 == 0:
            # Save model for this epoch
            torch.save(lstm, '../Pickle/' + saved_model_name_lstm + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            torch.save(neural_net, '../Pickle/' + saved_model_name_nn + '_e' + str(epoch) + '_b' + str(batch) + '.pth')

            # Save optimizer for this epoch
            torch.save(optimizer_lstm, '../Pickle/' + 'optim_lstm_domain_adapt_exp_3' + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            torch.save(optimizer_nn, '../Pickle/' + 'optim_nn_domain_adapt_exp_3' + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            
        if batch % 100 == 0:
            # Evaluate on dev set for AUC score
            dev_AUC_score = eval_model(lstm, dev_question_ids_android, data_android, word2vec, android_id_to_data_title, android_id_to_data_body,
                            word_to_id_vocab, truncation_val_title, truncation_val_body)

            print("Dev AUC score:", dev_AUC_score)
# Out:
# Working on batch #:  1
# lstm multi-margin loss on batch: 0.05727390944957733
# Neural net cross-entropy loss on batch: 0.6944898366928101
# Time_on_batch: 42.03669261932373
# Working on batch #:  2
# lstm multi-margin loss on batch: 0.04206767678260803
# Neural net cross-entropy loss on batch: 0.6935567259788513
# Time_on_batch: 55.459444761276245
# Working on batch #:  3
# lstm multi-margin loss on batch: 0.02788628824055195
# Neural net cross-entropy loss on batch: 0.6948354840278625
# Time_on_batch: 51.19212865829468
# Working on batch #:  4
# lstm multi-margin loss on batch: 0.01537452731281519
# Neural net cross-entropy loss on batch: 0.6943662762641907
# Time_on_batch: 41.82421851158142
# Working on batch #:  5
# lstm multi-margin loss on batch: 0.03313933685421944
# Neural net cross-entropy loss on batch: 0.6942253708839417
# Time_on_batch: 166.59056568145752
# Working on batch #:  6
# lstm multi-margin loss on batch: 0.007746235933154821
# Neural net cross-entropy loss on batch: 0.6936939358711243
# Time_on_batch: 56.9450900554657
# Working on batch #:  7
# lstm multi-margin loss on batch: 0.00784991029649973
# Neural net cross-entropy loss on batch: 0.6940435767173767
# Time_on_batch: 73.43722248077393
# Working on batch #:  8
# lstm multi-margin loss on batch: 0.007158328779041767
# Neural net cross-entropy loss on batch: 0.6942273378372192
# Time_on_batch: 51.07595944404602
# Working on batch #:  9
# lstm multi-margin loss on batch: 0.01383418869227171
# Neural net cross-entropy loss on batch: 0.6948229670524597
# Time_on_batch: 44.690362215042114
# Working on batch #:  10
# lstm multi-margin loss on batch: 0.010649356991052628
# Neural net cross-entropy loss on batch: 0.6931097507476807
# Time_on_batch: 110.21833062171936
# Working on batch #:  11
# lstm multi-margin loss on batch: 0.009478633292019367
# Neural net cross-entropy loss on batch: 0.6935201287269592
# Time_on_batch: 232.71487307548523
# Working on batch #:  12
# lstm multi-margin loss on batch: 0.03035937249660492
# Neural net cross-entropy loss on batch: 0.6943751573562622
# Time_on_batch: 58.78373098373413
# Working on batch #:  13
# lstm multi-margin loss on batch: 0.006528147496283054
# Neural net cross-entropy loss on batch: 0.6942857503890991
# Time_on_batch: 58.09380221366882
# Working on batch #:  14
# lstm multi-margin loss on batch: 0.00695415586233139
# Neural net cross-entropy loss on batch: 0.693891167640686
# Time_on_batch: 56.08613920211792
# Working on batch #:  15
# lstm multi-margin loss on batch: 0.010023820213973522
# Neural net cross-entropy loss on batch: 0.6932747960090637
# Time_on_batch: 60.51743292808533
# Working on batch #:  16
# lstm multi-margin loss on batch: 0.008775366470217705
# Neural net cross-entropy loss on batch: 0.6937167644500732
# Time_on_batch: 69.40456008911133
# Working on batch #:  17
# lstm multi-margin loss on batch: 0.008368346840143204
# Neural net cross-entropy loss on batch: 0.694064736366272
# Time_on_batch: 53.61256551742554
# Working on batch #:  18
# lstm multi-margin loss on batch: 0.00844232365489006
# Neural net cross-entropy loss on batch: 0.693900465965271
# Time_on_batch: 42.33858585357666
# Working on batch #:  19
# lstm multi-margin loss on batch: 0.01717056706547737
# Neural net cross-entropy loss on batch: 0.6940644383430481
# Time_on_batch: 48.015684366226196
# Working on batch #:  20
# lstm multi-margin loss on batch: 0.006387655157595873
# Neural net cross-entropy loss on batch: 0.6930641531944275
# Time_on_batch: 53.67072677612305
# Working on batch #:  21
# lstm multi-margin loss on batch: 0.005258113611489534
# Neural net cross-entropy loss on batch: 0.6935210227966309
# Time_on_batch: 44.42814302444458
# Working on batch #:  22
# lstm multi-margin loss on batch: 0.011849415488541126
# Neural net cross-entropy loss on batch: 0.6941317319869995
# Time_on_batch: 43.59492635726929
# Working on batch #:  23
# lstm multi-margin loss on batch: 0.007136133033782244
# Neural net cross-entropy loss on batch: 0.6930838823318481
# Time_on_batch: 69.63717722892761
# Working on batch #:  24
# lstm multi-margin loss on batch: 0.007593456655740738
# Neural net cross-entropy loss on batch: 0.6924412250518799
# Time_on_batch: 47.76501822471619
# Working on batch #:  25
# lstm multi-margin loss on batch: 0.008633331395685673
# Neural net cross-entropy loss on batch: 0.6929326057434082
# Time_on_batch: 48.16808581352234
# Working on batch #:  26
# lstm multi-margin loss on batch: 0.008521068841218948
# Neural net cross-entropy loss on batch: 0.6944094896316528
# Time_on_batch: 49.48960280418396
# Working on batch #:  27
# lstm multi-margin loss on batch: 0.005512637086212635
# Neural net cross-entropy loss on batch: 0.6920490264892578
# Time_on_batch: 39.574658155441284
# Working on batch #:  28
# lstm multi-margin loss on batch: 0.006934051401913166
# Neural net cross-entropy loss on batch: 0.6927510499954224
# Time_on_batch: 55.00266146659851
# Working on batch #:  29
# lstm multi-margin loss on batch: 0.010255946777760983
# Neural net cross-entropy loss on batch: 0.6936253309249878
# Time_on_batch: 47.43092370033264
# Working on batch #:  30
# lstm multi-margin loss on batch: 0.006862903945147991
# Neural net cross-entropy loss on batch: 0.6933172941207886
# Time_on_batch: 89.17766857147217
# Working on batch #:  31
# lstm multi-margin loss on batch: 0.02376101352274418
# Neural net cross-entropy loss on batch: 0.6929885149002075
# Time_on_batch: 48.38421678543091
# Working on batch #:  32
# lstm multi-margin loss on batch: 0.00537855876609683
# Neural net cross-entropy loss on batch: 0.6939533948898315
# Time_on_batch: 38.9933819770813
# Working on batch #:  33
# lstm multi-margin loss on batch: 0.0036118943244218826
# Neural net cross-entropy loss on batch: 0.6920474171638489
# Time_on_batch: 41.890446186065674
# Working on batch #:  34
# lstm multi-margin loss on batch: 0.005765331909060478
# Neural net cross-entropy loss on batch: 0.6916327476501465
# Time_on_batch: 43.1586799621582
# Working on batch #:  35
# lstm multi-margin loss on batch: 0.008914821781218052
# Neural net cross-entropy loss on batch: 0.6930642127990723
# Time_on_batch: 34.66243863105774
# Working on batch #:  36
# lstm multi-margin loss on batch: 0.007252486422657967
# Neural net cross-entropy loss on batch: 0.6921183466911316
# Time_on_batch: 39.83365321159363
# Working on batch #:  37
# lstm multi-margin loss on batch: 0.0054953680373728275
# Neural net cross-entropy loss on batch: 0.6926780343055725
# Time_on_batch: 45.07645511627197
# Working on batch #:  38
# lstm multi-margin loss on batch: 0.004339787643402815
# Neural net cross-entropy loss on batch: 0.692191481590271
# Time_on_batch: 37.77078604698181
# Working on batch #:  39
# lstm multi-margin loss on batch: 0.004969420842826366
# Neural net cross-entropy loss on batch: 0.692398190498352
# Time_on_batch: 60.074800968170166
# Working on batch #:  40
# lstm multi-margin loss on batch: 0.005607267841696739
# Neural net cross-entropy loss on batch: 0.6916114091873169
# Time_on_batch: 41.79012703895569
# Working on batch #:  41
# lstm multi-margin loss on batch: 0.0048976074904203415
# Neural net cross-entropy loss on batch: 0.6918647885322571
# Time_on_batch: 40.663790702819824
# Working on batch #:  42
# lstm multi-margin loss on batch: 0.00510450080037117
# Neural net cross-entropy loss on batch: 0.6922039985656738
# Time_on_batch: 73.35621237754822
# Working on batch #:  43
# lstm multi-margin loss on batch: 0.010199649259448051
# Neural net cross-entropy loss on batch: 0.6924343109130859
# Time_on_batch: 51.98688793182373
# Working on batch #:  44
# lstm multi-margin loss on batch: 0.01428072527050972
# Neural net cross-entropy loss on batch: 0.6915794610977173
# Time_on_batch: 238.48641514778137
# Working on batch #:  45
# lstm multi-margin loss on batch: 0.0038226130418479443
# Neural net cross-entropy loss on batch: 0.6919749975204468
# Time_on_batch: 41.89566445350647
# Working on batch #:  46
# lstm multi-margin loss on batch: 0.008256522007286549
# Neural net cross-entropy loss on batch: 0.6923582553863525
# Time_on_batch: 56.249757528305054
# Working on batch #:  47
# lstm multi-margin loss on batch: 0.008644581772387028
# Neural net cross-entropy loss on batch: 0.6922990083694458
# Time_on_batch: 54.87084698677063
# Working on batch #:  48
# lstm multi-margin loss on batch: 0.0034832374658435583
# Neural net cross-entropy loss on batch: 0.6916607618331909
# Time_on_batch: 53.72475814819336
# Working on batch #:  49
# lstm multi-margin loss on batch: 0.013807184994220734
# Neural net cross-entropy loss on batch: 0.690290093421936
# Time_on_batch: 55.08400106430054
# Working on batch #:  50
# lstm multi-margin loss on batch: 0.006610371172428131
# Neural net cross-entropy loss on batch: 0.69217848777771
# Time_on_batch: 44.69674897193909
# Working on batch #:  51
# lstm multi-margin loss on batch: 0.004995759576559067
# Neural net cross-entropy loss on batch: 0.6917600035667419
# Time_on_batch: 41.58535122871399
# Working on batch #:  52
# lstm multi-margin loss on batch: 0.0048829335719347
# Neural net cross-entropy loss on batch: 0.6908021569252014
# Time_on_batch: 57.686254262924194
# Working on batch #:  53
# lstm multi-margin loss on batch: 0.01044241152703762
# Neural net cross-entropy loss on batch: 0.6903677582740784
# Time_on_batch: 48.07637095451355
# Working on batch #:  54
# lstm multi-margin loss on batch: 0.004097806755453348
# Neural net cross-entropy loss on batch: 0.6917716264724731
# Time_on_batch: 69.78858041763306
# Working on batch #:  55
# lstm multi-margin loss on batch: 0.004644867964088917
# Neural net cross-entropy loss on batch: 0.6898016333580017
# Time_on_batch: 65.76789236068726
# Working on batch #:  56
# lstm multi-margin loss on batch: 0.007136030588299036
# Neural net cross-entropy loss on batch: 0.6918181777000427
# Time_on_batch: 40.56966209411621
# Working on batch #:  57
# lstm multi-margin loss on batch: 0.0037107476964592934
# Neural net cross-entropy loss on batch: 0.6908831000328064
# Time_on_batch: 40.47976112365723
# Working on batch #:  58
# lstm multi-margin loss on batch: 0.0036252846475690603
# Neural net cross-entropy loss on batch: 0.6911705136299133
# Time_on_batch: 50.02869153022766
# Working on batch #:  59
# lstm multi-margin loss on batch: 0.00473591685295105
# Neural net cross-entropy loss on batch: 0.6922791004180908
# Time_on_batch: 44.56336736679077
# Working on batch #:  60
# lstm multi-margin loss on batch: 0.003985950257629156
# Neural net cross-entropy loss on batch: 0.6919808983802795
# Time_on_batch: 54.56445932388306
# Working on batch #:  61
# lstm multi-margin loss on batch: 0.0035579497925937176
# Neural net cross-entropy loss on batch: 0.6911739706993103
# Time_on_batch: 65.33949327468872
# Working on batch #:  62
# lstm multi-margin loss on batch: 0.0034194462932646275
# Neural net cross-entropy loss on batch: 0.6903451681137085
# Time_on_batch: 128.64681339263916
# Working on batch #:  63
# lstm multi-margin loss on batch: 0.014362968504428864
# Neural net cross-entropy loss on batch: 0.6904033422470093
# Time_on_batch: 378.6649215221405
# Working on batch #:  64
# lstm multi-margin loss on batch: 0.005956569220870733
# Neural net cross-entropy loss on batch: 0.6910532712936401
# Time_on_batch: 45.27633047103882
# Working on batch #:  65
# lstm multi-margin loss on batch: 0.0037355676759034395
# Neural net cross-entropy loss on batch: 0.6915011405944824
# Time_on_batch: 64.6643762588501
# Working on batch #:  66
# lstm multi-margin loss on batch: 0.0049773165956139565
# Neural net cross-entropy loss on batch: 0.6912462115287781
# Time_on_batch: 50.411614418029785
# Working on batch #:  67
# lstm multi-margin loss on batch: 0.007431576959788799
# Neural net cross-entropy loss on batch: 0.6914004683494568
# Time_on_batch: 61.442386627197266
# Working on batch #:  68
# lstm multi-margin loss on batch: 0.008928671479225159
# Neural net cross-entropy loss on batch: 0.6910008788108826
# Time_on_batch: 46.20299220085144
# Working on batch #:  69
# lstm multi-margin loss on batch: 0.0018797296797856688
# Neural net cross-entropy loss on batch: 0.6887705326080322
# Time_on_batch: 286.17836904525757
# Working on batch #:  70
# lstm multi-margin loss on batch: 0.006483528297394514
# Neural net cross-entropy loss on batch: 0.6905010342597961
# Time_on_batch: 39.91291332244873
# Working on batch #:  71
# lstm multi-margin loss on batch: 0.0039626238867640495
# Neural net cross-entropy loss on batch: 0.6916592121124268
# Time_on_batch: 91.9493339061737
# Working on batch #:  72
# lstm multi-margin loss on batch: 0.011039813980460167
# Neural net cross-entropy loss on batch: 0.6884141564369202
# Time_on_batch: 42.90837812423706
# Working on batch #:  73
# lstm multi-margin loss on batch: 0.004633876495063305
# Neural net cross-entropy loss on batch: 0.691205620765686
# Time_on_batch: 35.5781524181366
# Working on batch #:  74
# lstm multi-margin loss on batch: 0.003933999687433243
# Neural net cross-entropy loss on batch: 0.6894539594650269
# Time_on_batch: 44.646273136138916
# Working on batch #:  75
# lstm multi-margin loss on batch: 0.004601402673870325
# Neural net cross-entropy loss on batch: 0.689473032951355
# Time_on_batch: 41.66640067100525
# Working on batch #:  76
# lstm multi-margin loss on batch: 0.007504797540605068
# Neural net cross-entropy loss on batch: 0.6902779340744019
# Time_on_batch: 34.3367338180542
# Working on batch #:  77
# lstm multi-margin loss on batch: 0.006458076182752848
# Neural net cross-entropy loss on batch: 0.6909353733062744
# Time_on_batch: 33.727710008621216
# Working on batch #:  78
# lstm multi-margin loss on batch: 0.004554281011223793
# Neural net cross-entropy loss on batch: 0.6904699802398682
# Time_on_batch: 34.31427240371704
# Working on batch #:  79
# lstm multi-margin loss on batch: 0.005184868350625038
# Neural net cross-entropy loss on batch: 0.6913905143737793
# Time_on_batch: 46.98494839668274
# Working on batch #:  80
# lstm multi-margin loss on batch: 0.002854615217074752
# Neural net cross-entropy loss on batch: 0.6899131536483765
# Time_on_batch: 37.04648232460022
# Working on batch #:  81
# lstm multi-margin loss on batch: 0.002344748005270958
# Neural net cross-entropy loss on batch: 0.6915794610977173
# Time_on_batch: 44.51840806007385
# Working on batch #:  82
# lstm multi-margin loss on batch: 0.0019190232269465923
# Neural net cross-entropy loss on batch: 0.6910263299942017
# Time_on_batch: 35.17453408241272
# Working on batch #:  83
# lstm multi-margin loss on batch: 0.0042127459309995174
# Neural net cross-entropy loss on batch: 0.6907321810722351
# Time_on_batch: 46.05246186256409
# Working on batch #:  84
# lstm multi-margin loss on batch: 0.0051610274240374565
# Neural net cross-entropy loss on batch: 0.6909076571464539
# Time_on_batch: 35.17952585220337
# Working on batch #:  85
# lstm multi-margin loss on batch: 0.002420953707769513
# Neural net cross-entropy loss on batch: 0.693162739276886
# Time_on_batch: 35.83231449127197
# Working on batch #:  86
# lstm multi-margin loss on batch: 0.003524237545207143
# Neural net cross-entropy loss on batch: 0.690727949142456
# Time_on_batch: 45.576189041137695
# Working on batch #:  87
# lstm multi-margin loss on batch: 0.004116478376090527
# Neural net cross-entropy loss on batch: 0.6892611980438232
# Time_on_batch: 40.113669633865356
# Working on batch #:  88
# lstm multi-margin loss on batch: 0.002489643869921565
# Neural net cross-entropy loss on batch: 0.690550684928894
# Time_on_batch: 43.76036620140076
# Working on batch #:  89
# lstm multi-margin loss on batch: 0.005606481339782476
# Neural net cross-entropy loss on batch: 0.6900191903114319
# Time_on_batch: 37.46963858604431
# Working on batch #:  90
# lstm multi-margin loss on batch: 0.0026867783162742853
# Neural net cross-entropy loss on batch: 0.6875690817832947
# Time_on_batch: 39.47095990180969
# Working on batch #:  91
# lstm multi-margin loss on batch: 0.004585679154843092
# Neural net cross-entropy loss on batch: 0.6894159913063049
# Time_on_batch: 41.6808602809906
# Working on batch #:  92
# lstm multi-margin loss on batch: 0.005952051375061274
# Neural net cross-entropy loss on batch: 0.6906486749649048
# Time_on_batch: 32.57158923149109
# Working on batch #:  94
# lstm multi-margin loss on batch: 0.0052556004375219345
# Neural net cross-entropy loss on batch: 0.6895342469215393
# Time_on_batch: 36.22234630584717
# Working on batch #:  95
# lstm multi-margin loss on batch: 0.0029784345533698797
# Neural net cross-entropy loss on batch: 0.6883824467658997
# Time_on_batch: 38.95957612991333
# Working on batch #:  96
# lstm multi-margin loss on batch: 0.005416865460574627
# Neural net cross-entropy loss on batch: 0.6888189315795898
# Time_on_batch: 36.38575744628906
# Working on batch #:  97
# lstm multi-margin loss on batch: 0.0032418756745755672
# Neural net cross-entropy loss on batch: 0.6902478933334351
# Time_on_batch: 34.303218364715576
# Working on batch #:  98
# lstm multi-margin loss on batch: 0.002363507403060794
# Neural net cross-entropy loss on batch: 0.6913065910339355
# Time_on_batch: 32.81125068664551
# Working on batch #:  99
# lstm multi-margin loss on batch: 0.007131865248084068
# Neural net cross-entropy loss on batch: 0.6885408163070679
# Time_on_batch: 142.42762660980225
# Working on batch #:  100
# lstm multi-margin loss on batch: 0.008276914246380329
# Neural net cross-entropy loss on batch: 0.6888967156410217
# Time_on_batch: 53.00249910354614
# 119685
# 0 2394 4788 7182 9576 11970 14364 16758 19152 21546 23940 26334 28728 31122 33516 35910 38304 40698 43092 45486 47880 50274 52668 55062 57456 59850 62244 64638 67032 69426 71820 74214 76608 79002 81396 83790 86184 88578 90972 93366 95760 98154 100548 102942 105336 107730 110124 112518 114912 117306 Dev AUC score: 0.726481034971
# Working on batch #:  101
# lstm multi-margin loss on batch: 0.0036201677285134792
# Neural net cross-entropy loss on batch: 0.6892288327217102
# Time_on_batch: 36.322588205337524
# Working on batch #:  102
# lstm multi-margin loss on batch: 0.007136214524507523
# Neural net cross-entropy loss on batch: 0.6896387934684753
# Time_on_batch: 33.748740911483765
# Working on batch #:  103
# lstm multi-margin loss on batch: 0.0026173139922320843
# Neural net cross-entropy loss on batch: 0.6904458403587341
# Time_on_batch: 34.462706327438354
# Working on batch #:  104
# lstm multi-margin loss on batch: 0.002968231216073036
# Neural net cross-entropy loss on batch: 0.6916681528091431
# Time_on_batch: 40.594974756240845
# Working on batch #:  105
# lstm multi-margin loss on batch: 0.004700782243162394
# Neural net cross-entropy loss on batch: 0.6895028352737427
# Time_on_batch: 33.96231031417847
# Working on batch #:  106
# lstm multi-margin loss on batch: 0.005085326731204987
# Neural net cross-entropy loss on batch: 0.6883018016815186
# Time_on_batch: 41.89939498901367
# Working on batch #:  107
# lstm multi-margin loss on batch: 0.004512088838964701
# Neural net cross-entropy loss on batch: 0.6883513331413269
# Time_on_batch: 38.40013813972473
# Working on batch #:  108
# lstm multi-margin loss on batch: 0.010552330873906612
# Neural net cross-entropy loss on batch: 0.6904022097587585
# Time_on_batch: 33.188228368759155
# Working on batch #:  109
# lstm multi-margin loss on batch: 0.005019145552068949
# Neural net cross-entropy loss on batch: 0.6877135634422302
# Time_on_batch: 35.71998572349548
# Working on batch #:  110
# lstm multi-margin loss on batch: 0.005605507642030716
# Neural net cross-entropy loss on batch: 0.6873958110809326
# Time_on_batch: 35.74407410621643
# Working on batch #:  111
# lstm multi-margin loss on batch: 0.006071881391108036
# Neural net cross-entropy loss on batch: 0.6892063617706299
# Time_on_batch: 42.46690273284912
# Working on batch #:  112
# lstm multi-margin loss on batch: 0.0044283331371843815
# Neural net cross-entropy loss on batch: 0.6881891489028931
# Time_on_batch: 35.97769474983215
# Working on batch #:  113
# lstm multi-margin loss on batch: 0.0037831678055226803
# Neural net cross-entropy loss on batch: 0.6889181733131409
# Time_on_batch: 43.05047941207886
# Working on batch #:  114
# lstm multi-margin loss on batch: 0.0034360361751168966
# Neural net cross-entropy loss on batch: 0.6878868341445923
# Time_on_batch: 42.040804624557495
# Working on batch #:  115
# lstm multi-margin loss on batch: 0.0041014691814780235
# Neural net cross-entropy loss on batch: 0.6875758171081543
# Time_on_batch: 38.0321409702301
# Working on batch #:  116
# lstm multi-margin loss on batch: 0.005121667869389057
# Neural net cross-entropy loss on batch: 0.6885630488395691
# Time_on_batch: 45.086894035339355
# Working on batch #:  117
# lstm multi-margin loss on batch: 0.00404129596427083
# Neural net cross-entropy loss on batch: 0.6901522278785706
# Time_on_batch: 34.807565689086914
# Working on batch #:  118
# lstm multi-margin loss on batch: 0.005110961850732565
# Neural net cross-entropy loss on batch: 0.6884108781814575
# Time_on_batch: 39.01273584365845
# Working on batch #:  119
# lstm multi-margin loss on batch: 0.0023489680606871843
# Neural net cross-entropy loss on batch: 0.68949955701828
# Time_on_batch: 36.654470443725586
# Working on batch #:  120
# lstm multi-margin loss on batch: 0.003822681726887822
# Neural net cross-entropy loss on batch: 0.6884482502937317
# Time_on_batch: 38.424177169799805
# Working on batch #:  121
# lstm multi-margin loss on batch: 0.001800528378225863
# Neural net cross-entropy loss on batch: 0.6903545260429382
# Time_on_batch: 36.980337142944336
# Working on batch #:  122
# lstm multi-margin loss on batch: 0.00616683904081583
# Neural net cross-entropy loss on batch: 0.6888148784637451
# Time_on_batch: 33.77782201766968
# Working on batch #:  123
# lstm multi-margin loss on batch: 0.007559275254607201
# Neural net cross-entropy loss on batch: 0.688520610332489
# Time_on_batch: 39.67750906944275
# Working on batch #:  124
# lstm multi-margin loss on batch: 0.004960604943335056
# Neural net cross-entropy loss on batch: 0.6889545917510986
# Time_on_batch: 43.415424823760986
# Working on batch #:  125
# lstm multi-margin loss on batch: 0.006486407481133938
# Neural net cross-entropy loss on batch: 0.68572998046875
# Time_on_batch: 37.958964347839355
# Working on batch #:  126
# lstm multi-margin loss on batch: 0.00248458213172853
# Neural net cross-entropy loss on batch: 0.6878186464309692
# Time_on_batch: 37.51776647567749
# Working on batch #:  127
# lstm multi-margin loss on batch: 0.005502473562955856
# Neural net cross-entropy loss on batch: 0.6887014508247375
# Time_on_batch: 41.349958181381226
# Working on batch #:  128
# lstm multi-margin loss on batch: 0.005681529175490141
# Neural net cross-entropy loss on batch: 0.6876043081283569
# Time_on_batch: 37.001407623291016
# Working on batch #:  129
# lstm multi-margin loss on batch: 0.002710103988647461
# Neural net cross-entropy loss on batch: 0.6879737973213196
# Time_on_batch: 50.96148943901062
# Working on batch #:  130
# lstm multi-margin loss on batch: 0.0027788979932665825
# Neural net cross-entropy loss on batch: 0.6870511770248413
# Time_on_batch: 49.75232648849487
# Working on batch #:  131
# lstm multi-margin loss on batch: 0.005344539415091276
# Neural net cross-entropy loss on batch: 0.6860634088516235
# Time_on_batch: 41.5635244846344
# Working on batch #:  132
# lstm multi-margin loss on batch: 0.0029756396543234587
# Neural net cross-entropy loss on batch: 0.6884947419166565
# Time_on_batch: 34.46865963935852
# Working on batch #:  133
# lstm multi-margin loss on batch: 0.0042024534195661545
# Neural net cross-entropy loss on batch: 0.6891761422157288
# Time_on_batch: 37.91281533241272
# Working on batch #:  134
# lstm multi-margin loss on batch: 0.003373032435774803
# Neural net cross-entropy loss on batch: 0.6863955855369568
# Time_on_batch: 51.17907118797302
# Working on batch #:  135
# lstm multi-margin loss on batch: 0.004128532484173775
# Neural net cross-entropy loss on batch: 0.688249409198761
# Time_on_batch: 53.31477355957031
# Working on batch #:  136
# lstm multi-margin loss on batch: 0.005010758526623249
# Neural net cross-entropy loss on batch: 0.6877340078353882
# Time_on_batch: 38.404196977615356
# Working on batch #:  137
# lstm multi-margin loss on batch: 0.003945465199649334
# Neural net cross-entropy loss on batch: 0.6871407628059387
# Time_on_batch: 34.426546573638916
# Working on batch #:  138
# lstm multi-margin loss on batch: 0.0037306188605725765
# Neural net cross-entropy loss on batch: 0.687202513217926
# Time_on_batch: 38.05218958854675
# Working on batch #:  139
# lstm multi-margin loss on batch: 0.003852507099509239
# Neural net cross-entropy loss on batch: 0.6861893534660339
# Time_on_batch: 47.31484293937683
# Working on batch #:  140
# lstm multi-margin loss on batch: 0.0034781298600137234
# Neural net cross-entropy loss on batch: 0.6851494312286377
# Time_on_batch: 36.67151427268982
# Working on batch #:  141
# lstm multi-margin loss on batch: 0.005086635705083609
# Neural net cross-entropy loss on batch: 0.6864619255065918
# Time_on_batch: 34.59902811050415
# Working on batch #:  142
# lstm multi-margin loss on batch: 0.003254010807722807
# Neural net cross-entropy loss on batch: 0.6856982111930847
# Time_on_batch: 43.61194849014282
# Working on batch #:  143
# lstm multi-margin loss on batch: 0.0030504707247018814
# Neural net cross-entropy loss on batch: 0.685950517654419
# Time_on_batch: 34.169893980026245
# Working on batch #:  144
# lstm multi-margin loss on batch: 0.0021354351192712784
# Neural net cross-entropy loss on batch: 0.6870973110198975
# Time_on_batch: 39.67950987815857
# Working on batch #:  145
# lstm multi-margin loss on batch: 0.0027688229456543922
# Neural net cross-entropy loss on batch: 0.6866629719734192
# Time_on_batch: 37.90178728103638
# Working on batch #:  146
# lstm multi-margin loss on batch: 0.0076998937875032425
# Neural net cross-entropy loss on batch: 0.6873549222946167
# Time_on_batch: 68.33369898796082
# Working on batch #:  147
# lstm multi-margin loss on batch: 0.00247102789580822
# Neural net cross-entropy loss on batch: 0.6853885054588318
# Time_on_batch: 39.741703033447266
# Working on batch #:  148
# lstm multi-margin loss on batch: 0.0045669665560126305
# Neural net cross-entropy loss on batch: 0.6863506436347961
# Time_on_batch: 39.56923007965088
# Working on batch #:  149
# lstm multi-margin loss on batch: 0.002292020246386528
# Neural net cross-entropy loss on batch: 0.6868152618408203
# Time_on_batch: 36.31259250640869
# Working on batch #:  150
# lstm multi-margin loss on batch: 0.0032185991294682026
# Neural net cross-entropy loss on batch: 0.6853412389755249
# Time_on_batch: 35.77811026573181
# Working on batch #:  151
# lstm multi-margin loss on batch: 0.0038655344396829605
# Neural net cross-entropy loss on batch: 0.6883927583694458
# Time_on_batch: 49.434478759765625
# Working on batch #:  152
# lstm multi-margin loss on batch: 0.005965963937342167
# Neural net cross-entropy loss on batch: 0.6868161559104919
# Time_on_batch: 100.0289695262909
# Working on batch #:  153
# lstm multi-margin loss on batch: 0.005515893921256065
# Neural net cross-entropy loss on batch: 0.682153582572937
# Time_on_batch: 45.90309381484985
# Working on batch #:  154
# lstm multi-margin loss on batch: 0.015161145478487015
# Neural net cross-entropy loss on batch: 0.6852871179580688
# Time_on_batch: 58.1465961933136
# Working on batch #:  155
# lstm multi-margin loss on batch: 0.004918023012578487
# Neural net cross-entropy loss on batch: 0.6853685975074768
# Time_on_batch: 41.51038575172424
# Working on batch #:  156
# lstm multi-margin loss on batch: 0.0034209478180855513
# Neural net cross-entropy loss on batch: 0.684070348739624
# Time_on_batch: 39.86904215812683
# Working on batch #:  157
# lstm multi-margin loss on batch: 0.005025862250477076
# Neural net cross-entropy loss on batch: 0.6845356225967407
# Time_on_batch: 38.207605600357056
# Working on batch #:  158
# lstm multi-margin loss on batch: 0.002771229948848486
# Neural net cross-entropy loss on batch: 0.6855266094207764
# Time_on_batch: 39.32356238365173
# Working on batch #:  159
# lstm multi-margin loss on batch: 0.005743307061493397
# Neural net cross-entropy loss on batch: 0.6846909523010254
# Time_on_batch: 48.26534128189087
# Working on batch #:  160
# lstm multi-margin loss on batch: 0.006580535788089037
# Neural net cross-entropy loss on batch: 0.6860662698745728
# Time_on_batch: 41.879369497299194
# Working on batch #:  161
# lstm multi-margin loss on batch: 0.00462244963273406
# Neural net cross-entropy loss on batch: 0.6832258105278015
# Time_on_batch: 37.07760190963745
# Working on batch #:  162
# lstm multi-margin loss on batch: 0.002015297068282962
# Neural net cross-entropy loss on batch: 0.6839455962181091
# Time_on_batch: 38.08526968955994
# Working on batch #:  163
# lstm multi-margin loss on batch: 0.004901221487671137
# Neural net cross-entropy loss on batch: 0.6845681667327881
# Time_on_batch: 42.55567669868469
# Working on batch #:  164
# lstm multi-margin loss on batch: 0.003885208396241069
# Neural net cross-entropy loss on batch: 0.6840440630912781
# Time_on_batch: 39.67628288269043
# Working on batch #:  165
# lstm multi-margin loss on batch: 0.0081987539306283
# Neural net cross-entropy loss on batch: 0.6835374236106873
# Time_on_batch: 45.04997253417969
# Working on batch #:  166
# lstm multi-margin loss on batch: 0.00806167908012867
# Neural net cross-entropy loss on batch: 0.680191695690155
# Time_on_batch: 70.30581045150757
# Working on batch #:  167
# lstm multi-margin loss on batch: 0.0052017453126609325
# Neural net cross-entropy loss on batch: 0.67951500415802
# Time_on_batch: 73.07500648498535
# Working on batch #:  168
# lstm multi-margin loss on batch: 0.003932449501007795
# Neural net cross-entropy loss on batch: 0.6822728514671326
# Time_on_batch: 35.16417598724365
# Working on batch #:  169
# lstm multi-margin loss on batch: 0.007117513567209244
# Neural net cross-entropy loss on batch: 0.6809642910957336
# Time_on_batch: 176.96189165115356
# Working on batch #:  170
# lstm multi-margin loss on batch: 0.0029386163223534822
# Neural net cross-entropy loss on batch: 0.6839982271194458
# Time_on_batch: 68.98281240463257
# Working on batch #:  171
# lstm multi-margin loss on batch: 0.0035017377231270075
# Neural net cross-entropy loss on batch: 0.6838492751121521
# Time_on_batch: 43.651121854782104
# Working on batch #:  172
# lstm multi-margin loss on batch: 0.001966254785656929
# Neural net cross-entropy loss on batch: 0.6835054755210876
# Time_on_batch: 39.52489185333252
# Working on batch #:  173
# lstm multi-margin loss on batch: 0.0029843670781701803
# Neural net cross-entropy loss on batch: 0.6834691166877747
# Time_on_batch: 46.55979800224304
# Working on batch #:  174
# lstm multi-margin loss on batch: 0.0030843508429825306
# Neural net cross-entropy loss on batch: 0.6812304854393005
# Time_on_batch: 34.78965640068054
# Working on batch #:  175
# lstm multi-margin loss on batch: 0.0040756165981292725
# Neural net cross-entropy loss on batch: 0.6803306341171265
# Time_on_batch: 38.239306926727295
# Working on batch #:  176
# lstm multi-margin loss on batch: 0.0046933116391301155
# Neural net cross-entropy loss on batch: 0.6820584535598755
# Time_on_batch: 39.57029747962952
# Working on batch #:  177
# lstm multi-margin loss on batch: 0.0028738335240632296
# Neural net cross-entropy loss on batch: 0.6833405494689941
# Time_on_batch: 39.77210783958435
# Working on batch #:  178
# lstm multi-margin loss on batch: 0.002984588500112295
# Neural net cross-entropy loss on batch: 0.6819807887077332
# Time_on_batch: 43.55945539474487
# Working on batch #:  179
# lstm multi-margin loss on batch: 0.004780035465955734
# Neural net cross-entropy loss on batch: 0.6811404228210449
# Time_on_batch: 38.244728088378906
# Working on batch #:  180
# lstm multi-margin loss on batch: 0.005331265274435282
# Neural net cross-entropy loss on batch: 0.6785181164741516
# Time_on_batch: 47.07017517089844
# Working on batch #:  181
# lstm multi-margin loss on batch: 0.003906088415533304
# Neural net cross-entropy loss on batch: 0.6806588172912598
# Time_on_batch: 56.66734433174133
# Working on batch #:  182
# lstm multi-margin loss on batch: 0.002211006125435233
# Neural net cross-entropy loss on batch: 0.6819918155670166
# Time_on_batch: 42.968637466430664
# Working on batch #:  183
# lstm multi-margin loss on batch: 0.0023248144425451756
# Neural net cross-entropy loss on batch: 0.680489182472229
# Time_on_batch: 41.55661106109619
# Working on batch #:  184
# lstm multi-margin loss on batch: 0.005385174416005611
# Neural net cross-entropy loss on batch: 0.6822824478149414
# Time_on_batch: 37.983001708984375
# Working on batch #:  185
# lstm multi-margin loss on batch: 0.0008629612275399268
# Neural net cross-entropy loss on batch: 0.6821907758712769
# Time_on_batch: 41.41011929512024
# Working on batch #:  186
# lstm multi-margin loss on batch: 0.004414339084178209
# Neural net cross-entropy loss on batch: 0.6763976216316223
# Time_on_batch: 38.58431696891785
# Working on batch #:  187
# lstm multi-margin loss on batch: 0.0029219596181064844
# Neural net cross-entropy loss on batch: 0.6782754063606262
# Time_on_batch: 40.15906882286072
# Working on batch #:  188
# lstm multi-margin loss on batch: 0.00310491188429296
# Neural net cross-entropy loss on batch: 0.6798039674758911
# Time_on_batch: 37.85142803192139
# Working on batch #:  189
# lstm multi-margin loss on batch: 0.005339216440916061
# Neural net cross-entropy loss on batch: 0.6784365177154541
# Time_on_batch: 51.87585210800171
# Working on batch #:  190
# lstm multi-margin loss on batch: 0.0022028284147381783
# Neural net cross-entropy loss on batch: 0.6842334270477295
# Time_on_batch: 40.497806549072266
# Working on batch #:  191
# lstm multi-margin loss on batch: 0.0029206883627921343
# Neural net cross-entropy loss on batch: 0.6778513193130493
# Time_on_batch: 38.962525367736816
# Working on batch #:  192
# lstm multi-margin loss on batch: 0.002112684305757284
# Neural net cross-entropy loss on batch: 0.6784216165542603
# Time_on_batch: 57.155266523361206
# Working on batch #:  193
# lstm multi-margin loss on batch: 0.0025188575964421034
# Neural net cross-entropy loss on batch: 0.6780117154121399
# Time_on_batch: 50.22607755661011
# Working on batch #:  194
# lstm multi-margin loss on batch: 0.0044075604528188705
# Neural net cross-entropy loss on batch: 0.6807971000671387
# Time_on_batch: 41.98817777633667
# Working on batch #:  195
# lstm multi-margin loss on batch: 0.0016850822139531374
# Neural net cross-entropy loss on batch: 0.678548276424408
# Time_on_batch: 39.21444606781006
# Working on batch #:  196
# lstm multi-margin loss on batch: 0.0031268722377717495
# Neural net cross-entropy loss on batch: 0.6820353269577026
# Time_on_batch: 67.33813333511353
# Working on batch #:  197
# lstm multi-margin loss on batch: 0.002187029691413045
# Neural net cross-entropy loss on batch: 0.6762112379074097
# Time_on_batch: 35.736592292785645
# Working on batch #:  198
# lstm multi-margin loss on batch: 0.004980946891009808
# Neural net cross-entropy loss on batch: 0.6770943403244019
# Time_on_batch: 41.852654695510864
# Working on batch #:  199
# lstm multi-margin loss on batch: 0.002282061381265521
# Neural net cross-entropy loss on batch: 0.6742552518844604
# Time_on_batch: 41.71054196357727
# Working on batch #:  200
# lstm multi-margin loss on batch: 0.007526937406510115
# Neural net cross-entropy loss on batch: 0.676957905292511
# Time_on_batch: 68.57208180427551
# 119685
# 0 2394 4788 7182 9576 11970 14364 16758 19152 21546 23940 26334 28728 31122 33516 35910 38304 40698 43092 45486 47880 50274 52668 55062 57456 59850 62244 64638 67032 69426 71820 74214 76608 79002 81396 83790 86184 88578 90972 93366 95760 98154 100548 102942 105336 107730 110124 112518 114912 117306 Dev AUC score: 0.748514831359
# Working on batch #:  201
# lstm multi-margin loss on batch: 0.001645781216211617
# Neural net cross-entropy loss on batch: 0.6748028993606567
# Time_on_batch: 37.739808797836304
# Working on batch #:  202
# lstm multi-margin loss on batch: 0.0038798791356384754
# Neural net cross-entropy loss on batch: 0.6746913194656372
# Time_on_batch: 42.189692735672
# Working on batch #:  203
# lstm multi-margin loss on batch: 0.004666372202336788
# Neural net cross-entropy loss on batch: 0.6751748323440552
# Time_on_batch: 42.43261098861694
# Working on batch #:  204
# lstm multi-margin loss on batch: 0.003754387842491269
# Neural net cross-entropy loss on batch: 0.6749160289764404
# Time_on_batch: 64.56829690933228
# Working on batch #:  205
# lstm multi-margin loss on batch: 0.0017688494408503175
# Neural net cross-entropy loss on batch: 0.6742466688156128
# Time_on_batch: 37.891857385635376
# Working on batch #:  206
# lstm multi-margin loss on batch: 0.0022942509967833757
# Neural net cross-entropy loss on batch: 0.680836021900177
# Time_on_batch: 56.70980167388916
# Working on batch #:  207
# lstm multi-margin loss on batch: 0.004039138555526733
# Neural net cross-entropy loss on batch: 0.6765585541725159
# Time_on_batch: 40.26081323623657
# Working on batch #:  208
# lstm multi-margin loss on batch: 0.0037460075691342354
# Neural net cross-entropy loss on batch: 0.6718391180038452
# Time_on_batch: 60.08989715576172
# Working on batch #:  209
# lstm multi-margin loss on batch: 0.0015324547421187162
# Neural net cross-entropy loss on batch: 0.6721615195274353
# Time_on_batch: 35.951080322265625
# Working on batch #:  210
# lstm multi-margin loss on batch: 0.003463887609541416
# Neural net cross-entropy loss on batch: 0.6720620393753052
# Time_on_batch: 39.69240117073059
# Working on batch #:  211
# lstm multi-margin loss on batch: 0.0015313681215047836
# Neural net cross-entropy loss on batch: 0.673828125
# Time_on_batch: 40.37706470489502
# Working on batch #:  212
# lstm multi-margin loss on batch: 0.0025386610068380833
# Neural net cross-entropy loss on batch: 0.6739621758460999
# Time_on_batch: 39.47097444534302
# Working on batch #:  213
# lstm multi-margin loss on batch: 0.0034567322582006454
# Neural net cross-entropy loss on batch: 0.6779795289039612
# Time_on_batch: 47.412184715270996
# Working on batch #:  214
# lstm multi-margin loss on batch: 0.002892047632485628
# Neural net cross-entropy loss on batch: 0.6708770990371704
# Time_on_batch: 45.84291219711304
# Working on batch #:  215
# lstm multi-margin loss on batch: 0.0042175608687102795
# Neural net cross-entropy loss on batch: 0.6760880947113037
# Time_on_batch: 39.82203030586243
# Working on batch #:  216
# lstm multi-margin loss on batch: 0.0024118581786751747
# Neural net cross-entropy loss on batch: 0.6705077886581421
# Time_on_batch: 44.250407218933105
# Working on batch #:  217
# lstm multi-margin loss on batch: 0.005821887869387865
# Neural net cross-entropy loss on batch: 0.6754906177520752
# Time_on_batch: 38.244690895080566
# Working on batch #:  218
# lstm multi-margin loss on batch: 0.003370958846062422
# Neural net cross-entropy loss on batch: 0.6722794771194458
# Time_on_batch: 38.9612512588501
# Working on batch #:  219
# lstm multi-margin loss on batch: 0.002737618051469326
# Neural net cross-entropy loss on batch: 0.6759549975395203
# Time_on_batch: 40.25593066215515
# Working on batch #:  220
# lstm multi-margin loss on batch: 0.0028012392576783895
# Neural net cross-entropy loss on batch: 0.6749756932258606
# Time_on_batch: 200.92229533195496
# Working on batch #:  221
# lstm multi-margin loss on batch: 0.004415187053382397
# Neural net cross-entropy loss on batch: 0.6728910207748413
# Time_on_batch: 64.27997994422913
# Working on batch #:  222
# lstm multi-margin loss on batch: 0.0026779668405652046
# Neural net cross-entropy loss on batch: 0.6764903664588928
# Time_on_batch: 40.3575644493103
# Working on batch #:  223
# lstm multi-margin loss on batch: 0.0021125993225723505
# Neural net cross-entropy loss on batch: 0.6757460832595825
# Time_on_batch: 39.18315076828003
# Working on batch #:  224
# lstm multi-margin loss on batch: 0.003969843965023756
# Neural net cross-entropy loss on batch: 0.6716574430465698
# Time_on_batch: 42.07445406913757
# Working on batch #:  225
# lstm multi-margin loss on batch: 0.0065116966143250465
# Neural net cross-entropy loss on batch: 0.6701654195785522
# Time_on_batch: 73.03808045387268
# Working on batch #:  226
# lstm multi-margin loss on batch: 0.003608206519857049
# Neural net cross-entropy loss on batch: 0.6713865995407104
# Time_on_batch: 47.31224513053894
# Working on batch #:  227
# lstm multi-margin loss on batch: 0.00638272799551487
# Neural net cross-entropy loss on batch: 0.6682226061820984
# Time_on_batch: 45.65648794174194
# Working on batch #:  228
# lstm multi-margin loss on batch: 0.003784778993576765
# Neural net cross-entropy loss on batch: 0.672511100769043
# Time_on_batch: 43.01528811454773
# Working on batch #:  229
# lstm multi-margin loss on batch: 0.0025867691729217768
# Neural net cross-entropy loss on batch: 0.6720449328422546
# Time_on_batch: 39.76180171966553
# Working on batch #:  230
# lstm multi-margin loss on batch: 0.0027657276950776577
# Neural net cross-entropy loss on batch: 0.6709960699081421
# Time_on_batch: 47.44121527671814
# Working on batch #:  231
# lstm multi-margin loss on batch: 0.0034179282374680042
# Neural net cross-entropy loss on batch: 0.6740925312042236
# Time_on_batch: 45.819666147232056
# Working on batch #:  232
# lstm multi-margin loss on batch: 0.005067624617367983
# Neural net cross-entropy loss on batch: 0.676895797252655
# Time_on_batch: 168.195627450943
# Working on batch #:  233
# lstm multi-margin loss on batch: 0.0029746894724667072
# Neural net cross-entropy loss on batch: 0.6692866683006287
# Time_on_batch: 43.2675895690918
# Working on batch #:  234
# lstm multi-margin loss on batch: 0.004227424971759319
# Neural net cross-entropy loss on batch: 0.6671298742294312
# Time_on_batch: 58.81135845184326
# Working on batch #:  235
# lstm multi-margin loss on batch: 0.0025426489301025867
# Neural net cross-entropy loss on batch: 0.6779674291610718
# Time_on_batch: 39.86971735954285
# Working on batch #:  236
# lstm multi-margin loss on batch: 0.0037398170679807663
# Neural net cross-entropy loss on batch: 0.6656625866889954
# Time_on_batch: 38.878978967666626
# Working on batch #:  237
# lstm multi-margin loss on batch: 0.002154468558728695
# Neural net cross-entropy loss on batch: 0.6651396155357361
# Time_on_batch: 39.55071544647217
# Working on batch #:  238
# lstm multi-margin loss on batch: 0.001740840612910688
# Neural net cross-entropy loss on batch: 0.6707776784896851
# Time_on_batch: 40.112565994262695
# Working on batch #:  239
# lstm multi-margin loss on batch: 0.004554593004286289
# Neural net cross-entropy loss on batch: 0.6652868986129761
# Time_on_batch: 40.880778312683105
# Working on batch #:  240
# lstm multi-margin loss on batch: 0.003314410336315632
# Neural net cross-entropy loss on batch: 0.6723513007164001
# Time_on_batch: 44.013198375701904
# Working on batch #:  241
# lstm multi-margin loss on batch: 0.004403278231620789
# Neural net cross-entropy loss on batch: 0.6653317213058472
# Time_on_batch: 45.5206835269928
# Working on batch #:  242
# lstm multi-margin loss on batch: 0.0009082817705348134
# Neural net cross-entropy loss on batch: 0.6728547811508179
# Time_on_batch: 37.86125040054321
# Working on batch #:  243
# lstm multi-margin loss on batch: 0.0028442491311579943
# Neural net cross-entropy loss on batch: 0.6667026281356812
# Time_on_batch: 365.8026804924011
# Working on batch #:  245
# lstm multi-margin loss on batch: 0.005263939965516329
# Neural net cross-entropy loss on batch: 0.6584728956222534
# Time_on_batch: 70.73557329177856
# Working on batch #:  246
# lstm multi-margin loss on batch: 0.002580438507720828
# Neural net cross-entropy loss on batch: 0.6643759608268738
# Time_on_batch: 62.480194330215454
# Working on batch #:  247
# lstm multi-margin loss on batch: 0.002394463401287794
# Neural net cross-entropy loss on batch: 0.6672482490539551
# Time_on_batch: 50.32024788856506
# Working on batch #:  248
# lstm multi-margin loss on batch: 0.0041051097214221954
# Neural net cross-entropy loss on batch: 0.6602744460105896
# Time_on_batch: 39.50205421447754
# Working on batch #:  249
# lstm multi-margin loss on batch: 0.003180277766659856
# Neural net cross-entropy loss on batch: 0.6680005192756653
# Time_on_batch: 41.87762999534607
# Working on batch #:  250
# lstm multi-margin loss on batch: 0.00293654203414917
# Neural net cross-entropy loss on batch: 0.6641553640365601
# Time_on_batch: 41.043184995651245
# Working on batch #:  251
# lstm multi-margin loss on batch: 0.003455572761595249
# Neural net cross-entropy loss on batch: 0.6639407873153687
# Time_on_batch: 162.12770676612854
# Working on batch #:  252
# lstm multi-margin loss on batch: 0.004704683553427458
# Neural net cross-entropy loss on batch: 0.6621415615081787
# Time_on_batch: 46.027528285980225
# Working on batch #:  253
# lstm multi-margin loss on batch: 0.010072534903883934
# Neural net cross-entropy loss on batch: 0.6627715229988098
# Time_on_batch: 207.69661569595337
# Working on batch #:  254
# lstm multi-margin loss on batch: 0.002465576399117708
# Neural net cross-entropy loss on batch: 0.6647568345069885
# Time_on_batch: 62.93677091598511
# Working on batch #:  255
# lstm multi-margin loss on batch: 0.0054749962873756886
# Neural net cross-entropy loss on batch: 0.6560354232788086
# Time_on_batch: 61.953880071640015
# Working on batch #:  256
# lstm multi-margin loss on batch: 0.003658309346064925
# Neural net cross-entropy loss on batch: 0.6656333208084106
# Time_on_batch: 45.51980137825012
# Working on batch #:  257
# lstm multi-margin loss on batch: 0.0031620932277292013
# Neural net cross-entropy loss on batch: 0.665208637714386
# Time_on_batch: 45.912883281707764
# Working on batch #:  258
# lstm multi-margin loss on batch: 0.0026386184617877007
# Neural net cross-entropy loss on batch: 0.6606888175010681
# Time_on_batch: 52.73264122009277
# Working on batch #:  259
# lstm multi-margin loss on batch: 0.0041773635894060135
# Neural net cross-entropy loss on batch: 0.6620379090309143
# Time_on_batch: 64.00252532958984
# Working on batch #:  260
# lstm multi-margin loss on batch: 0.0031422001775354147
# Neural net cross-entropy loss on batch: 0.6593081951141357
# Time_on_batch: 43.87617874145508
# Working on batch #:  261
# lstm multi-margin loss on batch: 0.004209878854453564
# Neural net cross-entropy loss on batch: 0.666836678981781
# Time_on_batch: 48.58885979652405
# Working on batch #:  262
# lstm multi-margin loss on batch: 0.0010947523405775428
# Neural net cross-entropy loss on batch: 0.6665621995925903
# Time_on_batch: 43.98237466812134
# Working on batch #:  263
# lstm multi-margin loss on batch: 0.0022073525469750166
# Neural net cross-entropy loss on batch: 0.6665775775909424
# Time_on_batch: 46.103405714035034
# Working on batch #:  264
# lstm multi-margin loss on batch: 0.0028921817429363728
# Neural net cross-entropy loss on batch: 0.6642593741416931
# Time_on_batch: 50.836865186691284
# Working on batch #:  265
# lstm multi-margin loss on batch: 0.003605838632211089
# Neural net cross-entropy loss on batch: 0.6554473638534546
# Time_on_batch: 41.82323908805847
# Working on batch #:  266
# lstm multi-margin loss on batch: 0.0031725121662020683
# Neural net cross-entropy loss on batch: 0.6664220094680786
# Time_on_batch: 46.68042016029358
# Working on batch #:  267
# lstm multi-margin loss on batch: 0.001383163034915924
# Neural net cross-entropy loss on batch: 0.6641451716423035
# Time_on_batch: 40.70398736000061
# Working on batch #:  268
# lstm multi-margin loss on batch: 0.0020742742344737053
# Neural net cross-entropy loss on batch: 0.6576200723648071
# Time_on_batch: 49.772393465042114
# Working on batch #:  269
# lstm multi-margin loss on batch: 0.003714313730597496
# Neural net cross-entropy loss on batch: 0.6680983304977417
# Time_on_batch: 41.05194330215454
# Working on batch #:  270
# lstm multi-margin loss on batch: 0.002957611344754696
# Neural net cross-entropy loss on batch: 0.6683050394058228
# Time_on_batch: 40.30547881126404
# Working on batch #:  271
# lstm multi-margin loss on batch: 0.004129268694669008
# Neural net cross-entropy loss on batch: 0.6612237691879272
# Time_on_batch: 54.35006332397461
# Working on batch #:  272
# lstm multi-margin loss on batch: 0.0025655056815594435
# Neural net cross-entropy loss on batch: 0.6560554504394531
# Time_on_batch: 44.831626653671265
# Working on batch #:  273
# lstm multi-margin loss on batch: 0.003169466508552432
# Neural net cross-entropy loss on batch: 0.6638326048851013
# Time_on_batch: 41.302191972732544
# Working on batch #:  274
# lstm multi-margin loss on batch: 0.004382187034934759
# Neural net cross-entropy loss on batch: 0.6675897240638733
# Time_on_batch: 42.05579972267151
# Working on batch #:  275
# lstm multi-margin loss on batch: 0.0014117059763520956
# Neural net cross-entropy loss on batch: 0.6620411276817322
# Time_on_batch: 62.157312870025635
# Working on batch #:  276
# lstm multi-margin loss on batch: 0.003543708473443985
# Neural net cross-entropy loss on batch: 0.6538461446762085
# Time_on_batch: 41.09558391571045
# Working on batch #:  277
# lstm multi-margin loss on batch: 0.004545154515653849
# Neural net cross-entropy loss on batch: 0.6586597561836243
# Time_on_batch: 75.90011310577393
# Working on batch #:  278
# lstm multi-margin loss on batch: 0.002360172802582383
# Neural net cross-entropy loss on batch: 0.6489479541778564
# Time_on_batch: 42.19248867034912
# Working on batch #:  279
# lstm multi-margin loss on batch: 0.004777008667588234
# Neural net cross-entropy loss on batch: 0.6523160338401794
# Time_on_batch: 53.40638756752014
# Working on batch #:  280
# lstm multi-margin loss on batch: 0.004973872099071741
# Neural net cross-entropy loss on batch: 0.6563769578933716
# Time_on_batch: 41.19900608062744
# Working on batch #:  281
# lstm multi-margin loss on batch: 0.002711595967411995
# Neural net cross-entropy loss on batch: 0.6532334685325623
# Time_on_batch: 41.96928548812866
# Working on batch #:  282
# lstm multi-margin loss on batch: 0.0025530154816806316
# Neural net cross-entropy loss on batch: 0.6547683477401733
# Time_on_batch: 40.58152937889099
# Working on batch #:  283
# lstm multi-margin loss on batch: 0.004209635779261589
# Neural net cross-entropy loss on batch: 0.6528319120407104
# Time_on_batch: 47.69181966781616
# Working on batch #:  284
# lstm multi-margin loss on batch: 0.002610445022583008
# Neural net cross-entropy loss on batch: 0.6444809436798096
# Time_on_batch: 43.30816459655762
# Working on batch #:  285
# lstm multi-margin loss on batch: 0.0021848182659596205
# Neural net cross-entropy loss on batch: 0.6553317904472351
# Time_on_batch: 40.412859201431274
# Working on batch #:  286
# lstm multi-margin loss on batch: 0.0023075267672538757
# Neural net cross-entropy loss on batch: 0.6406678557395935
# Time_on_batch: 56.17897343635559
# Working on batch #:  287
# lstm multi-margin loss on batch: 0.001889965613372624
# Neural net cross-entropy loss on batch: 0.6508423686027527
# Time_on_batch: 39.595385789871216
# Working on batch #:  288
# lstm multi-margin loss on batch: 0.003082193899899721
# Neural net cross-entropy loss on batch: 0.6426658630371094
# Time_on_batch: 42.77640223503113
# Working on batch #:  289
# lstm multi-margin loss on batch: 0.0012307389406487346
# Neural net cross-entropy loss on batch: 0.6568764448165894
# Time_on_batch: 46.65714383125305
# Working on batch #:  290
# lstm multi-margin loss on batch: 0.0033401192631572485
# Neural net cross-entropy loss on batch: 0.6443213224411011
# Time_on_batch: 46.32148575782776
# Working on batch #:  291
# lstm multi-margin loss on batch: 0.003175710793584585
# Neural net cross-entropy loss on batch: 0.6442278623580933
# Time_on_batch: 41.60778450965881
# Working on batch #:  292
# lstm multi-margin loss on batch: 0.002564840018749237
# Neural net cross-entropy loss on batch: 0.6389839053153992
# Time_on_batch: 202.69238209724426
# Working on batch #:  293
# lstm multi-margin loss on batch: 0.0035557516384869814
# Neural net cross-entropy loss on batch: 0.649237334728241
# Time_on_batch: 44.21441459655762
# Working on batch #:  294
# lstm multi-margin loss on batch: 0.0025208177976310253
# Neural net cross-entropy loss on batch: 0.6339026689529419
# Time_on_batch: 44.99572229385376
# Working on batch #:  295
# lstm multi-margin loss on batch: 0.0020437685307115316
# Neural net cross-entropy loss on batch: 0.6432498693466187
# Time_on_batch: 58.410985231399536
# Working on batch #:  296
# lstm multi-margin loss on batch: 0.0017630383372306824
# Neural net cross-entropy loss on batch: 0.6375046372413635
# Time_on_batch: 41.67875146865845
# Working on batch #:  297
# lstm multi-margin loss on batch: 0.0018519710283726454
# Neural net cross-entropy loss on batch: 0.6484915018081665
# Time_on_batch: 40.00549912452698
# Working on batch #:  298
# lstm multi-margin loss on batch: 0.0029935387428849936
# Neural net cross-entropy loss on batch: 0.6366440057754517
# Time_on_batch: 41.72049951553345
# Working on batch #:  299
# lstm multi-margin loss on batch: 0.0026918479707092047
# Neural net cross-entropy loss on batch: 0.6492602229118347
# Time_on_batch: 41.279701471328735
# Working on batch #:  300
# lstm multi-margin loss on batch: 0.001349157653748989
# Neural net cross-entropy loss on batch: 0.643800675868988
# Time_on_batch: 40.841552734375
# 119685
# 0 2394 4788 7182 9576 11970 14364 16758 19152 21546 23940 26334 28728 31122 33516 35910 38304 40698 43092 45486 47880 50274 52668 55062 57456 59850 62244 64638 67032 69426 71820 74214 76608 79002 81396 83790 86184 88578 90972 93366 95760 98154 100548 102942 105336 107730 110124 112518 114912 117306 Dev AUC score: 0.751034922245
# Working on batch #:  302
# lstm multi-margin loss on batch: 0.002541574649512768
# Neural net cross-entropy loss on batch: 0.6539074182510376
# Time_on_batch: 46.4916296005249
# Working on batch #:  303
# lstm multi-margin loss on batch: 0.004601951688528061
# Neural net cross-entropy loss on batch: 0.6455528140068054
# Time_on_batch: 48.84480881690979
# Working on batch #:  304
# lstm multi-margin loss on batch: 0.002025608904659748
# Neural net cross-entropy loss on batch: 0.633152425289154
# Time_on_batch: 45.52984356880188
# Working on batch #:  305
# lstm multi-margin loss on batch: 0.002306259237229824
# Neural net cross-entropy loss on batch: 0.6282853484153748
# Time_on_batch: 43.6907262802124
# Working on batch #:  306
# lstm multi-margin loss on batch: 0.002777657937258482
# Neural net cross-entropy loss on batch: 0.6399710178375244
# Time_on_batch: 41.948859214782715
# Working on batch #:  307
# lstm multi-margin loss on batch: 0.0015434707747772336
# Neural net cross-entropy loss on batch: 0.6455913782119751
# Time_on_batch: 42.6337673664093
# Working on batch #:  308
# lstm multi-margin loss on batch: 0.001969191711395979
# Neural net cross-entropy loss on batch: 0.6426264047622681
# Time_on_batch: 42.38495230674744
# Working on batch #:  309
# lstm multi-margin loss on batch: 0.0028300059493631124
# Neural net cross-entropy loss on batch: 0.63097083568573
# Time_on_batch: 41.718963861465454
# Working on batch #:  310
# lstm multi-margin loss on batch: 0.003935300745069981
# Neural net cross-entropy loss on batch: 0.6339579224586487
# Time_on_batch: 45.59843301773071
# Working on batch #:  311
# lstm multi-margin loss on batch: 0.0032430023420602083
# Neural net cross-entropy loss on batch: 0.6280115842819214
# Time_on_batch: 42.012139558792114
# Working on batch #:  312
# lstm multi-margin loss on batch: 0.002807059558108449
# Neural net cross-entropy loss on batch: 0.6364543437957764
# Time_on_batch: 48.577675580978394
# Working on batch #:  313
# lstm multi-margin loss on batch: 0.0020594564266502857
# Neural net cross-entropy loss on batch: 0.6320673227310181
# Time_on_batch: 43.1635308265686
# Working on batch #:  314
# lstm multi-margin loss on batch: 0.005066232290118933
# Neural net cross-entropy loss on batch: 0.6334173083305359
# Time_on_batch: 47.830427408218384
# Working on batch #:  315
# lstm multi-margin loss on batch: 0.0033666982781141996
# Neural net cross-entropy loss on batch: 0.6451375484466553
# Time_on_batch: 40.798311948776245
# Working on batch #:  316
# lstm multi-margin loss on batch: 0.002816587220877409
# Neural net cross-entropy loss on batch: 0.6436179280281067
# Time_on_batch: 43.44865918159485
# Working on batch #:  317
# lstm multi-margin loss on batch: 0.0038307206705212593
# Neural net cross-entropy loss on batch: 0.6403272151947021
# Time_on_batch: 42.27092719078064
# Working on batch #:  318
# lstm multi-margin loss on batch: 0.003226474393159151
# Neural net cross-entropy loss on batch: 0.6319634318351746
# Time_on_batch: 43.128223180770874

# %%
''' Encoder (LSTM) '''
#lstm_x = torch.load('../Pickle/lstm_domain_adapt_explore3_e0_b300.pth')

''' Procedural parameters '''
auc_scorer = AUCMeter()

# Evaluate on dev/test set for AUC score
test_AUC_score = eval_model(lstm, test_question_ids_android, test_data_android, word2vec, android_id_to_data_title, android_id_to_data_body,
                            word_to_id_vocab, truncation_val_title, truncation_val_body)

print("Test AUC score:", test_AUC_score)
# Out:
# 67569
# 0 1351 2702 4053 5404 6755 8106 9457 10808 12159 13510 14861 16212 17563 18914 20265 21616 22967 24318 25669 27020 28371 29722 31073 32424 33775 35126 36477 37828 39179 40530 41881 43232 44583 45934 47285 48636 49987 51338 52689 54040 55391 56742 58093 59444 60795 62146 63497 64848 66199 67550 Test AUC score: 0.771608200809
