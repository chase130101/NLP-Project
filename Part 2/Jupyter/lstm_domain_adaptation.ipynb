# %%
from parameters_lstm import *

from preprocess_datapoints_lstm import *
from preprocess_text_to_tensors_lstm import *
from domain_classifier_model_lstm import *
from meter import *

import torch
from torch.autograd import Variable
import time

saved_model_name_lstm = 'lstm_domain_adapt'
saved_model_name_nn = 'nn_domain_adapt'

# Initialize the data sets
processed_corpus = process_whole_corpuses()
word_to_id_vocab = processed_corpus['word_to_id']
word2vec = load_glove_embeddings(glove_path, word_to_id_vocab)
ubuntu_id_to_data_title = processed_corpus['ubuntu_id_to_data_title']
android_id_to_data_title = processed_corpus['android_id_to_data_title']
ubuntu_id_to_data_body = processed_corpus['ubuntu_id_to_data_body']
android_id_to_data_body = processed_corpus['android_id_to_data_body']


''' Data Sets '''
training_data_ubuntu = ubuntu_id_to_similar_different()
training_question_ids_ubuntu = list(training_data_ubuntu.keys())
dev_data_android = android_id_to_similar_different(dev=True)
dev_question_ids_android = list(dev_data_android.keys())
test_data_android = android_id_to_similar_different(dev=False)
test_question_ids_android = list(test_data_android.keys())
# Note: Remember to edit batch_size accordingly if testing on smaller size data sets

# %%
def eval_model(lstm, ids, data, word2vec, id2Data_title, id2Data_body, word_to_id_vocab, truncation_val_title, truncation_val_body):
    lstm.eval()
    auc_scorer.reset()

    candidate_ids, q_main_ids, labels = organize_test_ids(ids, data)
    num_q_main = len(q_main_ids)
    len_pieces = round(num_q_main/50)
    print(num_q_main)

    for i in range(0, num_q_main, len_pieces):
        print(i, end = ' ')
        q_main_id_num_repl_tuple = q_main_ids[i:i+len_pieces]
        candidates = candidate_ids[i:i+len_pieces]
        current_labels = torch.from_numpy(np.array(labels[i:i+len_pieces])).long()

        candidates_qs_matrix = construct_qs_matrix_testing(candidates, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        word_to_id_vocab, truncation_val_title, truncation_val_body, main=False)
        main_qs_matrix = construct_qs_matrix_testing(q_main_id_num_repl_tuple, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        word_to_id_vocab, truncation_val_title, truncation_val_body, main=True)

        similarity_matrix_this_batch = torch.nn.functional.cosine_similarity(candidates_qs_matrix, main_qs_matrix, eps=1e-8).data
        auc_scorer.add(similarity_matrix_this_batch, current_labels)

    auc_score = auc_scorer.value()

    return auc_score

# %%
''' Params Dashboard '''

''' Procedural parameters '''
batch_size = 40
num_differing_questions = 20
num_epochs = 2


''' Model specs LSTM '''
dropout = 0.3
margin = 0.1
lr_lstm = 10**-3

input_size = 300
hidden_size = 240
num_layers = 1
bias = True
batch_first = True
bidirectional = True
first_dim = num_layers * 2 if bidirectional else num_layers


''' Model specs NN '''
lr_nn = -10**-4
lamb = Variable(torch.ones(1) * 1e-3)

input_size_nn = 2*hidden_size if bidirectional else hidden_size
first_hidden_size_nn = 300
second_hidden_size_nn = 150


''' Data processing specs '''
truncation_val_title = 15
truncation_val_body = 85
padding_idx = 0

glove_path = '../glove.840B.300d.txt'
android_corpus_path = '../android_dataset/corpus.tsv'
ubuntu_corpus_path = '../ubuntu_dataset/text_tokenized.txt'

# %%
''' Encoder (LSTM) '''
lstm = torch.nn.LSTM(input_size, hidden_size, num_layers, bias, batch_first, dropout, bidirectional)
loss_function_lstm = torch.nn.MultiMarginLoss(margin=margin)
optimizer_lstm = torch.optim.Adam(lstm.parameters(), lr=lr_lstm, weight_decay = 0.00001)

h0 = Variable(torch.zeros(first_dim, 1, hidden_size), requires_grad=False)
c0 = Variable(torch.zeros(first_dim, 1, hidden_size), requires_grad=False)


''' Domain Classifier (Neural Net) '''
neural_net = DomainClassifier(input_size_nn, first_hidden_size_nn, second_hidden_size_nn)
loss_function_nn = nn.CrossEntropyLoss()
optimizer_nn = torch.optim.Adam(neural_net.parameters(), lr=lr_nn, weight_decay = 0.00001)


''' Procedural parameters '''
num_batches = round(len(training_question_ids_ubuntu) / batch_size)
auc_scorer = AUCMeter()


def train_lstm_question_similarity(lstm, batch_ids, batch_data, word2vec, id2Data_title, id2Data_body, word_to_id_vocab, truncation_val_title, truncation_val_body):
    lstm.train()
    sequence_ids, dict_sequence_lengths = organize_ids_training(batch_ids, batch_data, num_differing_questions)

    candidates_qs_tuples_matrix = construct_qs_matrix_training(sequence_ids, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        dict_sequence_lengths, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=True)
    main_qs_tuples_matrix = construct_qs_matrix_training(batch_ids, lstm, h0, c0, word2vec, id2Data_title, id2Data_body,
        dict_sequence_lengths, num_differing_questions, word_to_id_vocab, truncation_val_title, truncation_val_body, candidates=False)

    similarity_matrix = torch.nn.functional.cosine_similarity(candidates_qs_tuples_matrix, main_qs_tuples_matrix, dim=2, eps=1e-6)
    target = Variable(torch.LongTensor([0] * int(len(sequence_ids) / (1 + num_differing_questions))))
    loss_batch = loss_function_lstm(similarity_matrix, target)

    print("lstm multi-margin loss on batch:", loss_batch.data[0])
    return loss_batch


def train_nn_domain_classification(neural_net, lstm, h0, c0, ids_ubuntu, ids_android, word2vec,
    ubuntu_id_to_data_title, ubuntu_id_to_data_body, android_id_to_data_title, android_id_to_data_body, truncation_val_title, truncation_val_body):
    neural_net.train()
    lstm.train()

    qs_matrix_ubuntu = construct_qs_matrix_domain_classification(ids_ubuntu, lstm, h0, c0, word2vec,
        ubuntu_id_to_data_title, ubuntu_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body)
    qs_matrix_android = construct_qs_matrix_domain_classification(ids_android, lstm, h0, c0, word2vec,
        android_id_to_data_title, android_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body)
    overall_qs_matrix = torch.cat([qs_matrix_ubuntu, qs_matrix_android])

    out = neural_net.forward(overall_qs_matrix)
    softmax = torch.nn.Softmax()
    preds = torch.round(softmax(out)[:, 1].double()).data.numpy()
    target_vector = Variable(torch.cat([torch.zeros(20).long(), torch.ones(20).long()]))
    acc = np.sum(preds == target_vector.float().data.numpy())/len(preds)
    loss_batch = loss_function_nn(out.double(), target_vector)

    print("Neural net cross-entropy loss on batch:", loss_batch.data[0])
    print("Neural net accuracy on batch:", acc)
    return loss_batch.float()


'''Begin training'''
for epoch in range(num_epochs):

    # Train on whole training data set
    for batch in range(1, num_batches + 1):
        if batch == 93 or batch == 301:
            continue
        start = time.time()
        optimizer_lstm.zero_grad()
        optimizer_nn.zero_grad()
        print("Working on batch #: ", batch)

        # Train on ubuntu similar question retrieval
        ids_this_batch_for_lstm = training_question_ids_ubuntu[batch_size * (batch - 1):batch_size * batch]
        loss_batch_similarity = train_lstm_question_similarity(lstm, ids_this_batch_for_lstm,
        training_data_ubuntu, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body, word_to_id_vocab, truncation_val_title, truncation_val_body)

        # Train on ubuntu-android domain classification task
        ids_randomized_ubuntu = get_20_random_ids(training_question_ids_ubuntu)
        ids_randomized_android = get_20_random_ids(dev_question_ids_android)
        loss_batch_domain_classification = train_nn_domain_classification(neural_net, lstm, h0, c0,
            ids_randomized_ubuntu, ids_randomized_android, word2vec, ubuntu_id_to_data_title, ubuntu_id_to_data_body, android_id_to_data_title, android_id_to_data_body,
                                                                         truncation_val_title, truncation_val_body)

        # Overall loss = multi-margin loss - LAMBDA * cross entropy loss
        overall_loss = loss_batch_similarity - (lamb * loss_batch_domain_classification)
        print('Overall loss: ' + str(overall_loss.data[0]))
        overall_loss.backward()
        optimizer_lstm.step()
        optimizer_nn.step()

        print("Time on batch:", time.time() - start)
        
        if batch % 100 == 0:
            # Save model for this epoch
            torch.save(lstm, '../Pickle/' + saved_model_name_lstm + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            torch.save(neural_net, '../Pickle/' + saved_model_name_nn + '_e' + str(epoch) + '_b' + str(batch) + '.pth')

            # Save optimizer for this epoch
            torch.save(optimizer_lstm, '../Pickle/' + 'optim_lstm_domain_adapt' + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            torch.save(optimizer_nn, '../Pickle/' + 'optim_nn_domain_adapt' + '_e' + str(epoch) + '_b' + str(batch) + '.pth')
            
        if batch % 100 == 0:
            # Evaluate on dev set for AUC score
            dev_AUC_score = eval_model(lstm, dev_question_ids_android, dev_data_android, word2vec, android_id_to_data_title, android_id_to_data_body,
                            word_to_id_vocab, truncation_val_title, truncation_val_body)

            print("Dev AUC score:", dev_AUC_score)
# Out:
# Working on batch #:  1
# lstm multi-margin loss on batch: 0.056106001138687134
# Neural net cross-entropy loss on batch: 0.6945119236179902
# Neural net accuracy on batch: 0.5
# Overall loss: 0.05541148781776428
# Time on batch: 36.91167616844177
# Working on batch #:  2
# lstm multi-margin loss on batch: 0.03898945450782776
# Neural net cross-entropy loss on batch: 0.6950739237934738
# Neural net accuracy on batch: 0.5
# Overall loss: 0.03829438239336014
# Time on batch: 47.62154197692871
# Working on batch #:  3
# lstm multi-margin loss on batch: 0.028828946873545647
# Neural net cross-entropy loss on batch: 0.694450050310268
# Neural net accuracy on batch: 0.5
# Overall loss: 0.02813449688255787
# Time on batch: 46.985304832458496
# Working on batch #:  4
# lstm multi-margin loss on batch: 0.01979062147438526
# Neural net cross-entropy loss on batch: 0.6939695307018025
# Neural net accuracy on batch: 0.475
# Overall loss: 0.019096652045845985
# Time on batch: 35.69463324546814
# Working on batch #:  5
# lstm multi-margin loss on batch: 0.019588232040405273
# Neural net cross-entropy loss on batch: 0.6937793126869102
# Neural net accuracy on batch: 0.475
# Overall loss: 0.01889445260167122
# Time on batch: 164.66607451438904
# Working on batch #:  6
# lstm multi-margin loss on batch: 0.00821339525282383
# Neural net cross-entropy loss on batch: 0.6932206317740313
# Neural net accuracy on batch: 0.475
# Overall loss: 0.007520174607634544
# Time on batch: 48.11947441101074
# Working on batch #:  7
# lstm multi-margin loss on batch: 0.012659525498747826
# Neural net cross-entropy loss on batch: 0.6936974017706058
# Neural net accuracy on batch: 0.425
# Overall loss: 0.011965828016400337
# Time on batch: 66.11019325256348
# Working on batch #:  8
# lstm multi-margin loss on batch: 0.006435413844883442
# Neural net cross-entropy loss on batch: 0.6928770815134843
# Neural net accuracy on batch: 0.5
# Overall loss: 0.00574253685772419
# Time on batch: 37.518532276153564
# Working on batch #:  9
# lstm multi-margin loss on batch: 0.01396308932453394
# Neural net cross-entropy loss on batch: 0.6937284972974146
# Neural net accuracy on batch: 0.45
# Overall loss: 0.013269361108541489
# Time on batch: 33.746854066848755
# Working on batch #:  10
# lstm multi-margin loss on batch: 0.011822217144072056
# Neural net cross-entropy loss on batch: 0.6929561227317691
# Neural net accuracy on batch: 0.65
# Overall loss: 0.011129260994493961
# Time on batch: 66.41871047019958
# Working on batch #:  11
# lstm multi-margin loss on batch: 0.0172800961881876
# Neural net cross-entropy loss on batch: 0.6914473468260443
# Neural net accuracy on batch: 0.675
# Overall loss: 0.016588648781180382
# Time on batch: 160.50075912475586
# Working on batch #:  12
# lstm multi-margin loss on batch: 0.015111906453967094
# Neural net cross-entropy loss on batch: 0.6933059933982124
# Neural net accuracy on batch: 0.475
# Overall loss: 0.014418600127100945
# Time on batch: 39.14849829673767
# Working on batch #:  13
# lstm multi-margin loss on batch: 0.010015936568379402
# Neural net cross-entropy loss on batch: 0.692492053302715
# Neural net accuracy on batch: 0.6
# Overall loss: 0.009323444217443466
# Time on batch: 38.32700562477112
# Working on batch #:  14
# lstm multi-margin loss on batch: 0.008399782702326775
# Neural net cross-entropy loss on batch: 0.6924030734055864
# Neural net accuracy on batch: 0.625
# Overall loss: 0.007707379758358002
# Time on batch: 39.96514821052551
# Working on batch #:  15
# lstm multi-margin loss on batch: 0.009522092528641224
# Neural net cross-entropy loss on batch: 0.6913367633799103
# Neural net accuracy on batch: 0.7
# Overall loss: 0.008830755949020386
# Time on batch: 40.19013833999634
# Working on batch #:  16
# lstm multi-margin loss on batch: 0.004402909893542528
# Neural net cross-entropy loss on batch: 0.6916429391874418
# Neural net accuracy on batch: 0.65
# Overall loss: 0.0037112669087946415
# Time on batch: 45.78945779800415
# Working on batch #:  17
# lstm multi-margin loss on batch: 0.012335208244621754
# Neural net cross-entropy loss on batch: 0.691206336380604
# Neural net accuracy on batch: 0.65
# Overall loss: 0.011644002050161362
# Time on batch: 34.640503883361816
# Working on batch #:  18
# lstm multi-margin loss on batch: 0.010924139060080051
# Neural net cross-entropy loss on batch: 0.6907270467281782
# Neural net accuracy on batch: 0.675
# Overall loss: 0.010233411565423012
# Time on batch: 30.66248917579651
# Working on batch #:  19
# lstm multi-margin loss on batch: 0.009416553191840649
# Neural net cross-entropy loss on batch: 0.6913086007226958
# Neural net accuracy on batch: 0.7
# Overall loss: 0.008725244551897049
# Time on batch: 31.971863746643066
# Working on batch #:  20
# lstm multi-margin loss on batch: 0.00932225864380598
# Neural net cross-entropy loss on batch: 0.6913833554772759
# Neural net accuracy on batch: 0.65
# Overall loss: 0.008630875498056412
# Time on batch: 35.40285849571228
# Working on batch #:  21
# lstm multi-margin loss on batch: 0.006252160761505365
# Neural net cross-entropy loss on batch: 0.6896539027341136
# Neural net accuracy on batch: 0.675
# Overall loss: 0.00556250661611557
# Time on batch: 33.21907353401184
# Working on batch #:  22
# lstm multi-margin loss on batch: 0.01796574704349041
# Neural net cross-entropy loss on batch: 0.6905159369601417
# Neural net accuracy on batch: 0.675
# Overall loss: 0.017275230959057808
# Time on batch: 36.32575869560242
# Working on batch #:  23
# lstm multi-margin loss on batch: 0.007207625079900026
# Neural net cross-entropy loss on batch: 0.6897388995280549
# Neural net accuracy on batch: 0.775
# Overall loss: 0.006517886184155941
# Time on batch: 51.591726779937744
# Working on batch #:  24
# lstm multi-margin loss on batch: 0.0134730264544487
# Neural net cross-entropy loss on batch: 0.6880395121350917
# Neural net accuracy on batch: 0.825
# Overall loss: 0.012784986756742
# Time on batch: 34.02936792373657
# Working on batch #:  25
# lstm multi-margin loss on batch: 0.005842206068336964
# Neural net cross-entropy loss on batch: 0.6880579070025039
# Neural net accuracy on batch: 0.8
# Overall loss: 0.005154148209840059
# Time on batch: 32.50256896018982
# Working on batch #:  26
# lstm multi-margin loss on batch: 0.012911305762827396
# Neural net cross-entropy loss on batch: 0.6878396358218954
# Neural net accuracy on batch: 0.8
# Overall loss: 0.01222346629947424
# Time on batch: 34.77186679840088
# Working on batch #:  27
# lstm multi-margin loss on batch: 0.00399242015555501
# Neural net cross-entropy loss on batch: 0.6872142160626582
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0033052058424800634
# Time on batch: 31.30524468421936
# Working on batch #:  28
# lstm multi-margin loss on batch: 0.011920537799596786
# Neural net cross-entropy loss on batch: 0.6875143742747684
# Neural net accuracy on batch: 0.75
# Overall loss: 0.01123302336782217
# Time on batch: 43.416104793548584
# Working on batch #:  29
# lstm multi-margin loss on batch: 0.00888599082827568
# Neural net cross-entropy loss on batch: 0.6887001686451191
# Neural net accuracy on batch: 0.775
# Overall loss: 0.008197290822863579
# Time on batch: 34.495325803756714
# Working on batch #:  30
# lstm multi-margin loss on batch: 0.010508187115192413
# Neural net cross-entropy loss on batch: 0.6867868001504233
# Neural net accuracy on batch: 0.75
# Overall loss: 0.009821400046348572
# Time on batch: 64.42798709869385
# Working on batch #:  31
# lstm multi-margin loss on batch: 0.010275039821863174
# Neural net cross-entropy loss on batch: 0.686397007163508
# Neural net accuracy on batch: 0.8
# Overall loss: 0.009588642977178097
# Time on batch: 37.13460063934326
# Working on batch #:  32
# lstm multi-margin loss on batch: 0.003680403809994459
# Neural net cross-entropy loss on batch: 0.6848753930985911
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002995528280735016
# Time on batch: 32.09262251853943
# Working on batch #:  33
# lstm multi-margin loss on batch: 0.003278476418927312
# Neural net cross-entropy loss on batch: 0.6854574241390562
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0025930190458893776
# Time on batch: 34.91859769821167
# Working on batch #:  34
# lstm multi-margin loss on batch: 0.007059053517878056
# Neural net cross-entropy loss on batch: 0.6845400414996642
# Neural net accuracy on batch: 0.825
# Overall loss: 0.006374513264745474
# Time on batch: 36.01552414894104
# Working on batch #:  35
# lstm multi-margin loss on batch: 0.006076611578464508
# Neural net cross-entropy loss on batch: 0.6852191466132487
# Neural net accuracy on batch: 0.85
# Overall loss: 0.005391392391175032
# Time on batch: 32.14245653152466
# Working on batch #:  36
# lstm multi-margin loss on batch: 0.008519532158970833
# Neural net cross-entropy loss on batch: 0.6843812299920892
# Neural net accuracy on batch: 0.8
# Overall loss: 0.007835150696337223
# Time on batch: 32.41402316093445
# Working on batch #:  37
# lstm multi-margin loss on batch: 0.006537268869578838
# Neural net cross-entropy loss on batch: 0.6804288437471498
# Neural net accuracy on batch: 0.875
# Overall loss: 0.005856839939951897
# Time on batch: 36.30012083053589
# Working on batch #:  38
# lstm multi-margin loss on batch: 0.008851558901369572
# Neural net cross-entropy loss on batch: 0.6837988948520984
# Neural net accuracy on batch: 0.9
# Overall loss: 0.008167760446667671
# Time on batch: 34.738396883010864
# Working on batch #:  39
# lstm multi-margin loss on batch: 0.007221853826195002
# Neural net cross-entropy loss on batch: 0.6817909492231633
# Neural net accuracy on batch: 0.8
# Overall loss: 0.006540062837302685
# Time on batch: 50.09285068511963
# Working on batch #:  40
# lstm multi-margin loss on batch: 0.010506050661206245
# Neural net cross-entropy loss on batch: 0.6811433994137103
# Neural net accuracy on batch: 0.875
# Overall loss: 0.009824907407164574
# Time on batch: 32.231684923172
# Working on batch #:  41
# lstm multi-margin loss on batch: 0.006543965544551611
# Neural net cross-entropy loss on batch: 0.681050714760537
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0058629149571061134
# Time on batch: 34.58698558807373
# Working on batch #:  42
# lstm multi-margin loss on batch: 0.003611430060118437
# Neural net cross-entropy loss on batch: 0.6820278044762407
# Neural net accuracy on batch: 0.825
# Overall loss: 0.002929402282461524
# Time on batch: 62.02460479736328
# Working on batch #:  43
# lstm multi-margin loss on batch: 0.006660124287009239
# Neural net cross-entropy loss on batch: 0.6784893560602901
# Neural net accuracy on batch: 0.85
# Overall loss: 0.005981634836643934
# Time on batch: 44.4842574596405
# Working on batch #:  44
# lstm multi-margin loss on batch: 0.009244345128536224
# Neural net cross-entropy loss on batch: 0.6803959029909695
# Neural net accuracy on batch: 0.775
# Overall loss: 0.008563948795199394
# Time on batch: 199.45961666107178
# Working on batch #:  45
# lstm multi-margin loss on batch: 0.0037163225933909416
# Neural net cross-entropy loss on batch: 0.6803559600986225
# Neural net accuracy on batch: 0.775
# Overall loss: 0.0030359665397554636
# Time on batch: 37.66065549850464
# Working on batch #:  46
# lstm multi-margin loss on batch: 0.00964424293488264
# Neural net cross-entropy loss on batch: 0.680009024536911
# Neural net accuracy on batch: 0.8
# Overall loss: 0.00896423403173685
# Time on batch: 47.872923374176025
# Working on batch #:  47
# lstm multi-margin loss on batch: 0.005556335672736168
# Neural net cross-entropy loss on batch: 0.6774509239930171
# Neural net accuracy on batch: 0.8
# Overall loss: 0.004878884647041559
# Time on batch: 44.64126181602478
# Working on batch #:  48
# lstm multi-margin loss on batch: 0.004962132778018713
# Neural net cross-entropy loss on batch: 0.6700249333568398
# Neural net accuracy on batch: 0.85
# Overall loss: 0.004292107652872801
# Time on batch: 46.421422243118286
# Working on batch #:  49
# lstm multi-margin loss on batch: 0.01283037569373846
# Neural net cross-entropy loss on batch: 0.6785010240625092
# Neural net accuracy on batch: 0.8
# Overall loss: 0.012151874601840973
# Time on batch: 44.45509624481201
# Working on batch #:  50
# lstm multi-margin loss on batch: 0.0029026877600699663
# Neural net cross-entropy loss on batch: 0.6751519252649851
# Neural net accuracy on batch: 0.875
# Overall loss: 0.002227535704150796
# Time on batch: 37.36865735054016
# Working on batch #:  51
# lstm multi-margin loss on batch: 0.008797057904303074
# Neural net cross-entropy loss on batch: 0.6773756573991865
# Neural net accuracy on batch: 0.675
# Overall loss: 0.008119681850075722
# Time on batch: 32.727999210357666
# Working on batch #:  52
# lstm multi-margin loss on batch: 0.0036116137634962797
# Neural net cross-entropy loss on batch: 0.6763748136191688
# Neural net accuracy on batch: 0.75
# Overall loss: 0.002935238881036639
# Time on batch: 47.66285276412964
# Working on batch #:  53
# lstm multi-margin loss on batch: 0.006841088179498911
# Neural net cross-entropy loss on batch: 0.6713022705006604
# Neural net accuracy on batch: 0.85
# Overall loss: 0.006169785745441914
# Time on batch: 33.29467248916626
# Working on batch #:  54
# lstm multi-margin loss on batch: 0.006357440259307623
# Neural net cross-entropy loss on batch: 0.6661581173693599
# Neural net accuracy on batch: 0.875
# Overall loss: 0.005691281985491514
# Time on batch: 46.025413274765015
# Working on batch #:  55
# lstm multi-margin loss on batch: 0.008534358814358711
# Neural net cross-entropy loss on batch: 0.6740794639525601
# Neural net accuracy on batch: 0.825
# Overall loss: 0.007860279642045498
# Time on batch: 47.81310844421387
# Working on batch #:  56
# lstm multi-margin loss on batch: 0.007112662773579359
# Neural net cross-entropy loss on batch: 0.6658894410544907
# Neural net accuracy on batch: 0.875
# Overall loss: 0.006446773186326027
# Time on batch: 34.83865571022034
# Working on batch #:  57
# lstm multi-margin loss on batch: 0.008091630414128304
# Neural net cross-entropy loss on batch: 0.6672989428195575
# Neural net accuracy on batch: 0.85
# Overall loss: 0.007424331270158291
# Time on batch: 33.63611626625061
# Working on batch #:  58
# lstm multi-margin loss on batch: 0.0066298493184149265
# Neural net cross-entropy loss on batch: 0.6698331388357661
# Neural net accuracy on batch: 0.8
# Overall loss: 0.005960016045719385
# Time on batch: 34.834304332733154
# Working on batch #:  59
# lstm multi-margin loss on batch: 0.011327081359922886
# Neural net cross-entropy loss on batch: 0.6629845329062258
# Neural net accuracy on batch: 0.825
# Overall loss: 0.010664097033441067
# Time on batch: 36.77545619010925
# Working on batch #:  60
# lstm multi-margin loss on batch: 0.007354611996561289
# Neural net cross-entropy loss on batch: 0.6694209747386122
# Neural net accuracy on batch: 0.775
# Overall loss: 0.006685190834105015
# Time on batch: 43.28826546669006
# Working on batch #:  61
# lstm multi-margin loss on batch: 0.0041677700355648994
# Neural net cross-entropy loss on batch: 0.6648720223944997
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0035028979182243347
# Time on batch: 50.560415744781494
# Working on batch #:  62
# lstm multi-margin loss on batch: 0.01143307238817215
# Neural net cross-entropy loss on batch: 0.6656974498027879
# Neural net accuracy on batch: 0.8
# Overall loss: 0.010767375119030476
# Time on batch: 100.68790125846863
# Working on batch #:  63
# lstm multi-margin loss on batch: 0.01657406985759735
# Neural net cross-entropy loss on batch: 0.6576540463164187
# Neural net accuracy on batch: 0.975
# Overall loss: 0.01591641642153263
# Time on batch: 322.52332520484924
# Working on batch #:  64
# lstm multi-margin loss on batch: 0.010660451836884022
# Neural net cross-entropy loss on batch: 0.6642950274910798
# Neural net accuracy on batch: 0.875
# Overall loss: 0.009996157139539719
# Time on batch: 35.95131778717041
# Working on batch #:  65
# lstm multi-margin loss on batch: 0.0034505093935877085
# Neural net cross-entropy loss on batch: 0.6576208898267464
# Neural net accuracy on batch: 0.875
# Overall loss: 0.002792888320982456
# Time on batch: 35.21269392967224
# Working on batch #:  66
# lstm multi-margin loss on batch: 0.008187893778085709
# Neural net cross-entropy loss on batch: 0.6573743310231333
# Neural net accuracy on batch: 0.925
# Overall loss: 0.007530519273132086
# Time on batch: 42.667030811309814
# Working on batch #:  67
# lstm multi-margin loss on batch: 0.008105307817459106
# Neural net cross-entropy loss on batch: 0.6619585961387404
# Neural net accuracy on batch: 0.825
# Overall loss: 0.007443349342793226
# Time on batch: 42.00724911689758
# Working on batch #:  68
# lstm multi-margin loss on batch: 0.004466836340725422
# Neural net cross-entropy loss on batch: 0.6633757443516516
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0038034606259316206
# Time on batch: 34.235382080078125
# Working on batch #:  69
# lstm multi-margin loss on batch: 0.001682794070802629
# Neural net cross-entropy loss on batch: 0.649471627393559
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0010333224199712276
# Time on batch: 298.95687794685364
# Working on batch #:  70
# lstm multi-margin loss on batch: 0.009182392619550228
# Neural net cross-entropy loss on batch: 0.6522467504601639
# Neural net accuracy on batch: 0.95
# Overall loss: 0.00853014551103115
# Time on batch: 33.22250032424927
# Working on batch #:  71
# lstm multi-margin loss on batch: 0.004227119963616133
# Neural net cross-entropy loss on batch: 0.658078768657827
# Neural net accuracy on batch: 0.75
# Overall loss: 0.003569041145965457
# Time on batch: 66.1584153175354
# Working on batch #:  72
# lstm multi-margin loss on batch: 0.017941758036613464
# Neural net cross-entropy loss on batch: 0.657588077136099
# Neural net accuracy on batch: 0.85
# Overall loss: 0.017284169793128967
# Time on batch: 37.374834060668945
# Working on batch #:  73
# lstm multi-margin loss on batch: 0.004426118917763233
# Neural net cross-entropy loss on batch: 0.6499763532335636
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0037761423736810684
# Time on batch: 33.27031874656677
# Working on batch #:  74
# lstm multi-margin loss on batch: 0.004816892556846142
# Neural net cross-entropy loss on batch: 0.634583998592843
# Neural net accuracy on batch: 0.925
# Overall loss: 0.004182308446615934
# Time on batch: 36.99132251739502
# Working on batch #:  75
# lstm multi-margin loss on batch: 0.004605541005730629
# Neural net cross-entropy loss on batch: 0.6469424228321989
# Neural net accuracy on batch: 0.95
# Overall loss: 0.003958598710596561
# Time on batch: 35.31841015815735
# Working on batch #:  76
# lstm multi-margin loss on batch: 0.005446333903819323
# Neural net cross-entropy loss on batch: 0.6556252625466403
# Neural net accuracy on batch: 0.8
# Overall loss: 0.004790708422660828
# Time on batch: 33.57505822181702
# Working on batch #:  77
# lstm multi-margin loss on batch: 0.001939870766364038
# Neural net cross-entropy loss on batch: 0.6433528256422442
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0012965179048478603
# Time on batch: 32.10548424720764
# Working on batch #:  78
# lstm multi-margin loss on batch: 0.00399675453081727
# Neural net cross-entropy loss on batch: 0.6375873362071737
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0033591671381145716
# Time on batch: 33.06185746192932
# Working on batch #:  79
# lstm multi-margin loss on batch: 0.007346726953983307
# Neural net cross-entropy loss on batch: 0.6314660569909029
# Neural net accuracy on batch: 0.85
# Overall loss: 0.006715260911732912
# Time on batch: 42.269330978393555
# Working on batch #:  80
# lstm multi-margin loss on batch: 0.00546162249520421
# Neural net cross-entropy loss on batch: 0.6347278628701327
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004826894495636225
# Time on batch: 32.52812123298645
# Working on batch #:  81
# lstm multi-margin loss on batch: 0.00764651270583272
# Neural net cross-entropy loss on batch: 0.6363756869211076
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0070101371966302395
# Time on batch: 39.84034824371338
# Working on batch #:  82
# lstm multi-margin loss on batch: 0.0042375847697257996
# Neural net cross-entropy loss on batch: 0.6380227962813387
# Neural net accuracy on batch: 0.825
# Overall loss: 0.003599561983719468
# Time on batch: 33.70455765724182
# Working on batch #:  83
# lstm multi-margin loss on batch: 0.0034792153164744377
# Neural net cross-entropy loss on batch: 0.6364907206760342
# Neural net accuracy on batch: 0.925
# Overall loss: 0.0028427245561033487
# Time on batch: 39.73800086975098
# Working on batch #:  84
# lstm multi-margin loss on batch: 0.0042464532889425755
# Neural net cross-entropy loss on batch: 0.6415842352430595
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0036048691254109144
# Time on batch: 35.493672609329224
# Working on batch #:  85
# lstm multi-margin loss on batch: 0.0035103089176118374
# Neural net cross-entropy loss on batch: 0.6359653722347451
# Neural net accuracy on batch: 0.825
# Overall loss: 0.002874343656003475
# Time on batch: 35.28007793426514
# Working on batch #:  86
# lstm multi-margin loss on batch: 0.004859618376940489
# Neural net cross-entropy loss on batch: 0.6247418018857542
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004234876483678818
# Time on batch: 41.2982439994812
# Working on batch #:  87
# lstm multi-margin loss on batch: 0.005615012254565954
# Neural net cross-entropy loss on batch: 0.6457009018974956
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004969311412423849
# Time on batch: 36.385610580444336
# Working on batch #:  88
# lstm multi-margin loss on batch: 0.0017617351841181517
# Neural net cross-entropy loss on batch: 0.641534960303535
# Neural net accuracy on batch: 0.775
# Overall loss: 0.0011202001478523016
# Time on batch: 38.02647924423218
# Working on batch #:  89
# lstm multi-margin loss on batch: 0.0030539720319211483
# Neural net cross-entropy loss on batch: 0.6328336406456165
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0024211383424699306
# Time on batch: 31.93450355529785
# Working on batch #:  90
# lstm multi-margin loss on batch: 0.0054242354817688465
# Neural net cross-entropy loss on batch: 0.6247038070870683
# Neural net accuracy on batch: 0.85
# Overall loss: 0.004799531772732735
# Time on batch: 36.29292011260986
# Working on batch #:  91
# lstm multi-margin loss on batch: 0.006295991595834494
# Neural net cross-entropy loss on batch: 0.6254113616557131
# Neural net accuracy on batch: 0.85
# Overall loss: 0.005670580081641674
# Time on batch: 36.714492082595825
# Working on batch #:  92
# lstm multi-margin loss on batch: 0.007936134934425354
# Neural net cross-entropy loss on batch: 0.6077785624990886
# Neural net accuracy on batch: 1.0
# Overall loss: 0.007328356616199017
# Time on batch: 33.6529974937439
# Working on batch #:  94
# lstm multi-margin loss on batch: 0.0036634558346122503
# Neural net cross-entropy loss on batch: 0.6375324406104432
# Neural net accuracy on batch: 0.8
# Overall loss: 0.003025923389941454
# Time on batch: 35.60123896598816
# Working on batch #:  95
# lstm multi-margin loss on batch: 0.0036905838642269373
# Neural net cross-entropy loss on batch: 0.6217486735841227
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0030688350088894367
# Time on batch: 35.556743144989014
# Working on batch #:  96
# lstm multi-margin loss on batch: 0.006090717855840921
# Neural net cross-entropy loss on batch: 0.60638942353925
# Neural net accuracy on batch: 0.9
# Overall loss: 0.005484328605234623
# Time on batch: 32.71568322181702
# Working on batch #:  97
# lstm multi-margin loss on batch: 0.004457696806639433
# Neural net cross-entropy loss on batch: 0.6269124574044296
# Neural net accuracy on batch: 0.9
# Overall loss: 0.003830784233286977
# Time on batch: 34.04558992385864
# Working on batch #:  98
# lstm multi-margin loss on batch: 0.004354091361165047
# Neural net cross-entropy loss on batch: 0.610119864590023
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0037439714651554823
# Time on batch: 33.19328188896179
# Working on batch #:  99
# lstm multi-margin loss on batch: 0.01043914258480072
# Neural net cross-entropy loss on batch: 0.5961834843169432
# Neural net accuracy on batch: 0.925
# Overall loss: 0.009842959232628345
# Time on batch: 159.49983143806458
# Working on batch #:  100
# lstm multi-margin loss on batch: 0.009052527137100697
# Neural net cross-entropy loss on batch: 0.6013233250406984
# Neural net accuracy on batch: 0.9
# Overall loss: 0.008451203815639019
# Time on batch: 47.40267610549927
# 119685
# 0 2394 4788 7182 9576 11970 14364 16758 19152 21546 23940 26334 28728 31122 33516 35910 38304 40698 43092 45486 47880 50274 52668 55062 57456 59850 62244 64638 67032 69426 71820 74214 76608 79002 81396 83790 86184 88578 90972 93366 95760 98154 100548 102942 105336 107730 110124 112518 114912 117306 Test AUC score: 0.588590911331
# Working on batch #:  101
# lstm multi-margin loss on batch: 0.004498083610087633
# Neural net cross-entropy loss on batch: 0.6123952772374378
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0038856882601976395
# Time on batch: 36.852922201156616
# Working on batch #:  102
# lstm multi-margin loss on batch: 0.005180451087653637
# Neural net cross-entropy loss on batch: 0.6281117528686426
# Neural net accuracy on batch: 0.85
# Overall loss: 0.00455233920365572
# Time on batch: 35.16058921813965
# Working on batch #:  103
# lstm multi-margin loss on batch: 0.002827352611348033
# Neural net cross-entropy loss on batch: 0.588807352545464
# Neural net accuracy on batch: 0.95
# Overall loss: 0.002238545101135969
# Time on batch: 35.00248098373413
# Working on batch #:  104
# lstm multi-margin loss on batch: 0.00650456827133894
# Neural net cross-entropy loss on batch: 0.5753122326615954
# Neural net accuracy on batch: 0.975
# Overall loss: 0.005929255858063698
# Time on batch: 36.192949056625366
# Working on batch #:  105
# lstm multi-margin loss on batch: 0.006785592529922724
# Neural net cross-entropy loss on batch: 0.6022912150090963
# Neural net accuracy on batch: 0.9
# Overall loss: 0.006183301098644733
# Time on batch: 34.574055194854736
# Working on batch #:  106
# lstm multi-margin loss on batch: 0.007765198592096567
# Neural net cross-entropy loss on batch: 0.6006697088862775
# Neural net accuracy on batch: 0.85
# Overall loss: 0.00716452905908227
# Time on batch: 38.284149408340454
# Working on batch #:  107
# lstm multi-margin loss on batch: 0.006348751485347748
# Neural net cross-entropy loss on batch: 0.5926844158842168
# Neural net accuracy on batch: 0.875
# Overall loss: 0.005756067112088203
# Time on batch: 35.277503490448
# Working on batch #:  108
# lstm multi-margin loss on batch: 0.004695462062954903
# Neural net cross-entropy loss on batch: 0.6202866817138186
# Neural net accuracy on batch: 0.825
# Overall loss: 0.004075175151228905
# Time on batch: 33.77126502990723
# Working on batch #:  109
# lstm multi-margin loss on batch: 0.005786357447504997
# Neural net cross-entropy loss on batch: 0.6054606024800326
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0051808967255055904
# Time on batch: 36.12908387184143
# Working on batch #:  110
# lstm multi-margin loss on batch: 0.010479654185473919
# Neural net cross-entropy loss on batch: 0.6046044759127945
# Neural net accuracy on batch: 0.85
# Overall loss: 0.009875049814581871
# Time on batch: 36.7655189037323
# Working on batch #:  111
# lstm multi-margin loss on batch: 0.007070400286465883
# Neural net cross-entropy loss on batch: 0.5888509046335808
# Neural net accuracy on batch: 0.925
# Overall loss: 0.006481549236923456
# Time on batch: 40.67114496231079
# Working on batch #:  112
# lstm multi-margin loss on batch: 0.007375592365860939
# Neural net cross-entropy loss on batch: 0.5757758930272734
# Neural net accuracy on batch: 0.825
# Overall loss: 0.006799816619604826
# Time on batch: 38.494011640548706
# Working on batch #:  113
# lstm multi-margin loss on batch: 0.005431243684142828
# Neural net cross-entropy loss on batch: 0.6155670735370775
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004815676715224981
# Time on batch: 40.63645887374878
# Working on batch #:  114
# lstm multi-margin loss on batch: 0.0073110382072627544
# Neural net cross-entropy loss on batch: 0.5894218008958613
# Neural net accuracy on batch: 0.8
# Overall loss: 0.006721616256982088
# Time on batch: 37.2897891998291
# Working on batch #:  115
# lstm multi-margin loss on batch: 0.006932664662599564
# Neural net cross-entropy loss on batch: 0.5643596814809408
# Neural net accuracy on batch: 0.85
# Overall loss: 0.006368305068463087
# Time on batch: 34.628682374954224
# Working on batch #:  116
# lstm multi-margin loss on batch: 0.006544339470565319
# Neural net cross-entropy loss on batch: 0.6105108192747188
# Neural net accuracy on batch: 0.825
# Overall loss: 0.00593382865190506
# Time on batch: 43.32900786399841
# Working on batch #:  117
# lstm multi-margin loss on batch: 0.008089668117463589
# Neural net cross-entropy loss on batch: 0.5885210484317499
# Neural net accuracy on batch: 0.775
# Overall loss: 0.007501147221773863
# Time on batch: 34.70789313316345
# Working on batch #:  118
# lstm multi-margin loss on batch: 0.007257438264787197
# Neural net cross-entropy loss on batch: 0.6046848100131469
# Neural net accuracy on batch: 0.8
# Overall loss: 0.006652753334492445
# Time on batch: 34.19369101524353
# Working on batch #:  119
# lstm multi-margin loss on batch: 0.0035627984907478094
# Neural net cross-entropy loss on batch: 0.5918844510837449
# Neural net accuracy on batch: 0.85
# Overall loss: 0.002970913890749216
# Time on batch: 39.06225824356079
# Working on batch #:  120
# lstm multi-margin loss on batch: 0.0057623982429504395
# Neural net cross-entropy loss on batch: 0.5944899095607723
# Neural net accuracy on batch: 0.8
# Overall loss: 0.005167908035218716
# Time on batch: 35.04113817214966
# Working on batch #:  121
# lstm multi-margin loss on batch: 0.0026992259081453085
# Neural net cross-entropy loss on batch: 0.5642958226300503
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002134930109605193
# Time on batch: 36.782374143600464
# Working on batch #:  122
# lstm multi-margin loss on batch: 0.011127081699669361
# Neural net cross-entropy loss on batch: 0.5365670967157761
# Neural net accuracy on batch: 0.975
# Overall loss: 0.010590514168143272
# Time on batch: 34.51032614707947
# Working on batch #:  123
# lstm multi-margin loss on batch: 0.006900652777403593
# Neural net cross-entropy loss on batch: 0.574664547993108
# Neural net accuracy on batch: 0.875
# Overall loss: 0.006325988098978996
# Time on batch: 37.192681312561035
# Working on batch #:  124
# lstm multi-margin loss on batch: 0.0029759693425148726
# Neural net cross-entropy loss on batch: 0.5876411987402999
# Neural net accuracy on batch: 0.8
# Overall loss: 0.002388328080996871
# Time on batch: 39.06506896018982
# Working on batch #:  125
# lstm multi-margin loss on batch: 0.008495342917740345
# Neural net cross-entropy loss on batch: 0.5630570283507041
# Neural net accuracy on batch: 0.925
# Overall loss: 0.007932285778224468
# Time on batch: 33.17310404777527
# Working on batch #:  126
# lstm multi-margin loss on batch: 0.002074325690045953
# Neural net cross-entropy loss on batch: 0.5417519590372495
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0015325737185776234
# Time on batch: 33.861093521118164
# Working on batch #:  127
# lstm multi-margin loss on batch: 0.008635951206088066
# Neural net cross-entropy loss on batch: 0.5301674323636407
# Neural net accuracy on batch: 0.9
# Overall loss: 0.008105783723294735
# Time on batch: 37.21142315864563
# Working on batch #:  128
# lstm multi-margin loss on batch: 0.0063201915472745895
# Neural net cross-entropy loss on batch: 0.5584725863512875
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0057617188431322575
# Time on batch: 38.55113363265991
# Working on batch #:  129
# lstm multi-margin loss on batch: 0.007730202749371529
# Neural net cross-entropy loss on batch: 0.5555879726874322
# Neural net accuracy on batch: 0.9
# Overall loss: 0.007174614816904068
# Time on batch: 47.98473525047302
# Working on batch #:  130
# lstm multi-margin loss on batch: 0.00653541786596179
# Neural net cross-entropy loss on batch: 0.5545262705335824
# Neural net accuracy on batch: 0.8
# Overall loss: 0.005980891641229391
# Time on batch: 45.471110582351685
# Working on batch #:  131
# lstm multi-margin loss on batch: 0.008991277776658535
# Neural net cross-entropy loss on batch: 0.560879148104619
# Neural net accuracy on batch: 0.9
# Overall loss: 0.008430399000644684
# Time on batch: 36.41231107711792
# Working on batch #:  132
# lstm multi-margin loss on batch: 0.004443637561053038
# Neural net cross-entropy loss on batch: 0.5467008437616706
# Neural net accuracy on batch: 0.85
# Overall loss: 0.003896936774253845
# Time on batch: 35.958871603012085
# Working on batch #:  133
# lstm multi-margin loss on batch: 0.00414517754688859
# Neural net cross-entropy loss on batch: 0.5579292323392959
# Neural net accuracy on batch: 0.825
# Overall loss: 0.003587248269468546
# Time on batch: 37.39095687866211
# Working on batch #:  134
# lstm multi-margin loss on batch: 0.011739248409867287
# Neural net cross-entropy loss on batch: 0.5204220981729331
# Neural net accuracy on batch: 0.925
# Overall loss: 0.011218826286494732
# Time on batch: 47.37109088897705
# Working on batch #:  135
# lstm multi-margin loss on batch: 0.00432566786184907
# Neural net cross-entropy loss on batch: 0.5328378649829693
# Neural net accuracy on batch: 0.8
# Overall loss: 0.0037928300444036722
# Time on batch: 49.98298478126526
# Working on batch #:  136
# lstm multi-margin loss on batch: 0.007796240504831076
# Neural net cross-entropy loss on batch: 0.5271074775551482
# Neural net accuracy on batch: 0.9
# Overall loss: 0.007269132882356644
# Time on batch: 34.270535707473755
# Working on batch #:  137
# lstm multi-margin loss on batch: 0.00813310220837593
# Neural net cross-entropy loss on batch: 0.5037431060576671
# Neural net accuracy on batch: 0.9
# Overall loss: 0.007629359140992165
# Time on batch: 36.29784893989563
# Working on batch #:  138
# lstm multi-margin loss on batch: 0.016526805236935616
# Neural net cross-entropy loss on batch: 0.5136502392731558
# Neural net accuracy on batch: 0.95
# Overall loss: 0.01601315476000309
# Time on batch: 37.59382963180542
# Working on batch #:  139
# lstm multi-margin loss on batch: 0.003356078639626503
# Neural net cross-entropy loss on batch: 0.47370510910499614
# Neural net accuracy on batch: 0.95
# Overall loss: 0.00288237351924181
# Time on batch: 41.693284034729004
# Working on batch #:  140
# lstm multi-margin loss on batch: 0.0025243598502129316
# Neural net cross-entropy loss on batch: 0.4987720460920274
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0020255877170711756
# Time on batch: 33.267252922058105
# Working on batch #:  141
# lstm multi-margin loss on batch: 0.006182648241519928
# Neural net cross-entropy loss on batch: 0.4972883477236126
# Neural net accuracy on batch: 0.875
# Overall loss: 0.005685359705239534
# Time on batch: 35.27334403991699
# Working on batch #:  142
# lstm multi-margin loss on batch: 0.0029223060701042414
# Neural net cross-entropy loss on batch: 0.49547040887321325
# Neural net accuracy on batch: 0.925
# Overall loss: 0.002426835708320141
# Time on batch: 39.35275745391846
# Working on batch #:  143
# lstm multi-margin loss on batch: 0.0038204563315957785
# Neural net cross-entropy loss on batch: 0.49676979843154206
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0033236865419894457
# Time on batch: 35.38406991958618
# Working on batch #:  144
# lstm multi-margin loss on batch: 0.002517039654776454
# Neural net cross-entropy loss on batch: 0.536157269266243
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0019808823708444834
# Time on batch: 36.28215503692627
# Working on batch #:  145
# lstm multi-margin loss on batch: 0.00503773195669055
# Neural net cross-entropy loss on batch: 0.5071580963193951
# Neural net accuracy on batch: 0.8
# Overall loss: 0.004530573729425669
# Time on batch: 37.53644156455994
# Working on batch #:  146
# lstm multi-margin loss on batch: 0.006865022238343954
# Neural net cross-entropy loss on batch: 0.5528231006590868
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0063121989369392395
# Time on batch: 64.1745285987854
# Working on batch #:  147
# lstm multi-margin loss on batch: 0.0047318884171545506
# Neural net cross-entropy loss on batch: 0.4826359726021166
# Neural net accuracy on batch: 0.925
# Overall loss: 0.004249252378940582
# Time on batch: 34.42670965194702
# Working on batch #:  148
# lstm multi-margin loss on batch: 0.0030275715980678797
# Neural net cross-entropy loss on batch: 0.4887793942830233
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002538792323321104
# Time on batch: 35.292787075042725
# Working on batch #:  149
# lstm multi-margin loss on batch: 0.005375060718506575
# Neural net cross-entropy loss on batch: 0.5094782202620654
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004865582566708326
# Time on batch: 36.991307497024536
# Working on batch #:  150
# lstm multi-margin loss on batch: 0.00560716912150383
# Neural net cross-entropy loss on batch: 0.48737661153336037
# Neural net accuracy on batch: 0.825
# Overall loss: 0.005119792651385069
# Time on batch: 36.13207721710205
# Working on batch #:  151
# lstm multi-margin loss on batch: 0.005081361625343561
# Neural net cross-entropy loss on batch: 0.474223846275838
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004607137758284807
# Time on batch: 44.38702726364136
# Working on batch #:  152
# lstm multi-margin loss on batch: 0.007334032095968723
# Neural net cross-entropy loss on batch: 0.4850945729479769
# Neural net accuracy on batch: 0.85
# Overall loss: 0.00684893736615777
# Time on batch: 93.68545508384705
# Working on batch #:  153
# lstm multi-margin loss on batch: 0.009959143586456776
# Neural net cross-entropy loss on batch: 0.4416555821211928
# Neural net accuracy on batch: 0.95
# Overall loss: 0.009517488069832325
# Time on batch: 43.337127685546875
# Working on batch #:  154
# lstm multi-margin loss on batch: 0.005295334383845329
# Neural net cross-entropy loss on batch: 0.45175209612106715
# Neural net accuracy on batch: 0.9
# Overall loss: 0.004843582399189472
# Time on batch: 53.452385902404785
# Working on batch #:  155
# lstm multi-margin loss on batch: 0.005407796241343021
# Neural net cross-entropy loss on batch: 0.45930314381515214
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004948493093252182
# Time on batch: 37.46743726730347
# Working on batch #:  156
# lstm multi-margin loss on batch: 0.004544628318399191
# Neural net cross-entropy loss on batch: 0.4843480241246664
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004060280509293079
# Time on batch: 36.59646439552307
# Working on batch #:  157
# lstm multi-margin loss on batch: 0.008122124709188938
# Neural net cross-entropy loss on batch: 0.5909567163738708
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0075311679393053055
# Time on batch: 32.74547100067139
# Working on batch #:  158
# lstm multi-margin loss on batch: 0.0040104868821799755
# Neural net cross-entropy loss on batch: 0.4543137356572321
# Neural net accuracy on batch: 0.9
# Overall loss: 0.003556173061951995
# Time on batch: 35.12804055213928
# Working on batch #:  159
# lstm multi-margin loss on batch: 0.006129383109509945
# Neural net cross-entropy loss on batch: 0.47239146046120456
# Neural net accuracy on batch: 0.9
# Overall loss: 0.005656991619616747
# Time on batch: 40.3578417301178
# Working on batch #:  160
# lstm multi-margin loss on batch: 0.008700587786734104
# Neural net cross-entropy loss on batch: 0.4295067665276215
# Neural net accuracy on batch: 0.9
# Overall loss: 0.008271081373095512
# Time on batch: 37.50186586380005
# Working on batch #:  161
# lstm multi-margin loss on batch: 0.006390605587512255
# Neural net cross-entropy loss on batch: 0.5657692095596627
# Neural net accuracy on batch: 0.75
# Overall loss: 0.005824836436659098
# Time on batch: 32.89625883102417
# Working on batch #:  162
# lstm multi-margin loss on batch: 0.002835774328559637
# Neural net cross-entropy loss on batch: 0.40108345387175354
# Neural net accuracy on batch: 0.975
# Overall loss: 0.002434690948575735
# Time on batch: 39.65277862548828
# Working on batch #:  163
# lstm multi-margin loss on batch: 0.007138183806091547
# Neural net cross-entropy loss on batch: 0.5058053665986662
# Neural net accuracy on batch: 0.85
# Overall loss: 0.006632378324866295
# Time on batch: 37.2980682849884
# Working on batch #:  164
# lstm multi-margin loss on batch: 0.006104983389377594
# Neural net cross-entropy loss on batch: 0.4850507527220046
# Neural net accuracy on batch: 0.825
# Overall loss: 0.005619932431727648
# Time on batch: 41.485626459121704
# Working on batch #:  165
# lstm multi-margin loss on batch: 0.0088338702917099
# Neural net cross-entropy loss on batch: 0.4708298485227235
# Neural net accuracy on batch: 0.85
# Overall loss: 0.008363040164113045
# Time on batch: 42.712061643600464
# Working on batch #:  166
# lstm multi-margin loss on batch: 0.005592143628746271
# Neural net cross-entropy loss on batch: 0.40544744290419166
# Neural net accuracy on batch: 0.925
# Overall loss: 0.005186696071177721
# Time on batch: 68.39709782600403
# Working on batch #:  167
# lstm multi-margin loss on batch: 0.008915596641600132
# Neural net cross-entropy loss on batch: 0.45634849263601307
# Neural net accuracy on batch: 0.875
# Overall loss: 0.008459248580038548
# Time on batch: 68.81336522102356
# Working on batch #:  168
# lstm multi-margin loss on batch: 0.00407744012773037
# Neural net cross-entropy loss on batch: 0.46065802266872724
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0036167821381241083
# Time on batch: 36.095038652420044
# Working on batch #:  169
# lstm multi-margin loss on batch: 0.005314338486641645
# Neural net cross-entropy loss on batch: 0.4251129417069189
# Neural net accuracy on batch: 0.9
# Overall loss: 0.004889225587248802
# Time on batch: 173.81054735183716
# Working on batch #:  170
# lstm multi-margin loss on batch: 0.0025148659478873014
# Neural net cross-entropy loss on batch: 0.43814785186436034
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0020767180249094963
# Time on batch: 45.134947061538696
# Working on batch #:  171
# lstm multi-margin loss on batch: 0.0061824144795536995
# Neural net cross-entropy loss on batch: 0.43313716881076314
# Neural net accuracy on batch: 0.975
# Overall loss: 0.005749277304857969
# Time on batch: 40.205251932144165
# Working on batch #:  172
# lstm multi-margin loss on batch: 0.0037323383148759604
# Neural net cross-entropy loss on batch: 0.4979916292511303
# Neural net accuracy on batch: 0.8
# Overall loss: 0.003234346630051732
# Time on batch: 44.11856269836426
# Working on batch #:  173
# lstm multi-margin loss on batch: 0.004330973140895367
# Neural net cross-entropy loss on batch: 0.4439480648070854
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0038870251737535
# Time on batch: 40.53797197341919
# Working on batch #:  174
# lstm multi-margin loss on batch: 0.0033927259501069784
# Neural net cross-entropy loss on batch: 0.4537464953473943
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0029389793053269386
# Time on batch: 35.217458963394165
# Working on batch #:  175
# lstm multi-margin loss on batch: 0.004910478834062815
# Neural net cross-entropy loss on batch: 0.46063380019875355
# Neural net accuracy on batch: 0.85
# Overall loss: 0.00444984482601285
# Time on batch: 33.915536403656006
# Working on batch #:  176
# lstm multi-margin loss on batch: 0.0024881218560039997
# Neural net cross-entropy loss on batch: 0.4267210517113081
# Neural net accuracy on batch: 0.825
# Overall loss: 0.002061400795355439
# Time on batch: 35.237666845321655
# Working on batch #:  177
# lstm multi-margin loss on batch: 0.0038298103027045727
# Neural net cross-entropy loss on batch: 0.43666206993411427
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0033931483048945665
# Time on batch: 33.67167925834656
# Working on batch #:  178
# lstm multi-margin loss on batch: 0.002506530610844493
# Neural net cross-entropy loss on batch: 0.39314882877198304
# Neural net accuracy on batch: 0.925
# Overall loss: 0.002113381866365671
# Time on batch: 38.1531777381897
# Working on batch #:  179
# lstm multi-margin loss on batch: 0.0041902451775968075
# Neural net cross-entropy loss on batch: 0.38132417490124426
# Neural net accuracy on batch: 0.975
# Overall loss: 0.003808920970186591
# Time on batch: 37.63205814361572
# Working on batch #:  180
# lstm multi-margin loss on batch: 0.00680966954678297
# Neural net cross-entropy loss on batch: 0.4270850196493908
# Neural net accuracy on batch: 0.875
# Overall loss: 0.006382584571838379
# Time on batch: 43.937113523483276
# Working on batch #:  181
# lstm multi-margin loss on batch: 0.004156752489507198
# Neural net cross-entropy loss on batch: 0.40189187521152575
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0037548604886978865
# Time on batch: 51.043872594833374
# Working on batch #:  182
# lstm multi-margin loss on batch: 0.007063708268105984
# Neural net cross-entropy loss on batch: 0.46301378920914615
# Neural net accuracy on batch: 0.85
# Overall loss: 0.006600694265216589
# Time on batch: 38.30581092834473
# Working on batch #:  183
# lstm multi-margin loss on batch: 0.004312862642109394
# Neural net cross-entropy loss on batch: 0.42121836564830684
# Neural net accuracy on batch: 0.925
# Overall loss: 0.003891644300892949
# Time on batch: 36.764995098114014
# Working on batch #:  184
# lstm multi-margin loss on batch: 0.007196253165602684
# Neural net cross-entropy loss on batch: 0.3778866136953696
# Neural net accuracy on batch: 0.925
# Overall loss: 0.006818366702646017
# Time on batch: 38.99220132827759
# Working on batch #:  185
# lstm multi-margin loss on batch: 0.002775103785097599
# Neural net cross-entropy loss on batch: 0.4441744575070655
# Neural net accuracy on batch: 0.825
# Overall loss: 0.002330929273739457
# Time on batch: 37.1953547000885
# Working on batch #:  186
# lstm multi-margin loss on batch: 0.005938692484050989
# Neural net cross-entropy loss on batch: 0.3816692149465116
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0055570234544575214
# Time on batch: 38.42308020591736
# Working on batch #:  187
# lstm multi-margin loss on batch: 0.005409384611994028
# Neural net cross-entropy loss on batch: 0.4039164642980257
# Neural net accuracy on batch: 0.9
# Overall loss: 0.005005468148738146
# Time on batch: 34.1865873336792
# Working on batch #:  188
# lstm multi-margin loss on batch: 0.007508115377277136
# Neural net cross-entropy loss on batch: 0.40896213377942275
# Neural net accuracy on batch: 0.85
# Overall loss: 0.007099153473973274
# Time on batch: 37.59071969985962
# Working on batch #:  189
# lstm multi-margin loss on batch: 0.007975173182785511
# Neural net cross-entropy loss on batch: 0.4531125824750838
# Neural net accuracy on batch: 0.875
# Overall loss: 0.007522060535848141
# Time on batch: 46.480103731155396
# Working on batch #:  190
# lstm multi-margin loss on batch: 0.002189535414800048
# Neural net cross-entropy loss on batch: 0.5060119726173802
# Neural net accuracy on batch: 0.8
# Overall loss: 0.0016835234127938747
# Time on batch: 35.23737454414368
# Working on batch #:  191
# lstm multi-margin loss on batch: 0.00366226676851511
# Neural net cross-entropy loss on batch: 0.42087651703884943
# Neural net accuracy on batch: 0.825
# Overall loss: 0.003241390222683549
# Time on batch: 42.36930775642395
# Working on batch #:  192
# lstm multi-margin loss on batch: 0.002865167800337076
# Neural net cross-entropy loss on batch: 0.3917109526833609
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002473456785082817
# Time on batch: 52.48765277862549
# Working on batch #:  193
# lstm multi-margin loss on batch: 0.0040015652775764465
# Neural net cross-entropy loss on batch: 0.5212336892858902
# Neural net accuracy on batch: 0.775
# Overall loss: 0.0034803315065801144
# Time on batch: 45.081605195999146
# Working on batch #:  194
# lstm multi-margin loss on batch: 0.00528002018108964
# Neural net cross-entropy loss on batch: 0.3841728013080244
# Neural net accuracy on batch: 0.85
# Overall loss: 0.004895847290754318
# Time on batch: 36.857553005218506
# Working on batch #:  195
# lstm multi-margin loss on batch: 0.004003018140792847
# Neural net cross-entropy loss on batch: 0.3746359096795088
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0036283822264522314
# Time on batch: 37.755403995513916
# Working on batch #:  196
# lstm multi-margin loss on batch: 0.006349555682390928
# Neural net cross-entropy loss on batch: 0.4259642133537002
# Neural net accuracy on batch: 0.925
# Overall loss: 0.0059235915541648865
# Time on batch: 61.70491909980774
# Working on batch #:  197
# lstm multi-margin loss on batch: 0.005456971470266581
# Neural net cross-entropy loss on batch: 0.4249775409604072
# Neural net accuracy on batch: 0.875
# Overall loss: 0.005031994078308344
# Time on batch: 35.469995737075806
# Working on batch #:  198
# lstm multi-margin loss on batch: 0.0057013314217329025
# Neural net cross-entropy loss on batch: 0.31028598201147267
# Neural net accuracy on batch: 0.975
# Overall loss: 0.005391045473515987
# Time on batch: 36.5273973941803
# Working on batch #:  199
# lstm multi-margin loss on batch: 0.0026781412307173014
# Neural net cross-entropy loss on batch: 0.3877109024891053
# Neural net accuracy on batch: 0.9
# ...
# Working on batch #:  243
# lstm multi-margin loss on batch: 0.008189438842236996
# Neural net cross-entropy loss on batch: 0.3882008720245911
# Neural net accuracy on batch: 0.825
# Overall loss: 0.007801237981766462
# Time on batch: 421.7608091831207
# Working on batch #:  244
# lstm multi-margin loss on batch: 0.0031428555957973003
# Neural net cross-entropy loss on batch: 0.36881658666165407
# Neural net accuracy on batch: 0.9
# Overall loss: 0.00277403905056417
# Time on batch: 44.23370575904846
# Working on batch #:  245
# lstm multi-margin loss on batch: 0.002872896147891879
# Neural net cross-entropy loss on batch: 0.3909495714597168
# Neural net accuracy on batch: 0.85
# Overall loss: 0.002481946488842368
# Time on batch: 56.750858783721924
# Working on batch #:  246
# lstm multi-margin loss on batch: 0.005128087941557169
# Neural net cross-entropy loss on batch: 0.3864696985729771
# Neural net accuracy on batch: 0.875
# Overall loss: 0.004741618409752846
# Time on batch: 38.969003438949585
# Working on batch #:  247
# lstm multi-margin loss on batch: 0.0031930042896419764
# Neural net cross-entropy loss on batch: 0.36848285308481854
# Neural net accuracy on batch: 0.875
# Overall loss: 0.002824521390721202
# Time on batch: 42.14433217048645
# Working on batch #:  248
# lstm multi-margin loss on batch: 0.0038775315042585135
# Neural net cross-entropy loss on batch: 0.4219283388897727
# Neural net accuracy on batch: 0.95
# Overall loss: 0.003455603029578924
# Time on batch: 38.273550271987915
# Working on batch #:  249
# lstm multi-margin loss on batch: 0.005899036768823862
# Neural net cross-entropy loss on batch: 0.3507888986479625
# Neural net accuracy on batch: 0.925
# Overall loss: 0.005548248067498207
# Time on batch: 39.74699282646179
# Working on batch #:  250
# lstm multi-margin loss on batch: 0.0027777287177741528
# Neural net cross-entropy loss on batch: 0.33056504069588166
# Neural net accuracy on batch: 0.95
# Overall loss: 0.002447163686156273
# Time on batch: 40.15629458427429
# Working on batch #:  251
# lstm multi-margin loss on batch: 0.006841856054961681
# Neural net cross-entropy loss on batch: 0.3625552139055975
# Neural net accuracy on batch: 0.875
# Overall loss: 0.006479301024228334
# Time on batch: 151.2504961490631
# Working on batch #:  252
# lstm multi-margin loss on batch: 0.004578559193760157
# Neural net cross-entropy loss on batch: 0.31323896091535647
# Neural net accuracy on batch: 0.925
# Overall loss: 0.004265320021659136
# Time on batch: 43.85268211364746
# Working on batch #:  253
# lstm multi-margin loss on batch: 0.007777377963066101
# Neural net cross-entropy loss on batch: 0.38586096146351634
# Neural net accuracy on batch: 0.9
# Overall loss: 0.007391517050564289
# Time on batch: 214.64576649665833
# Working on batch #:  254
# lstm multi-margin loss on batch: 0.007287577260285616
# Neural net cross-entropy loss on batch: 0.3966073441299371
# Neural net accuracy on batch: 0.875
# Overall loss: 0.006890969816595316
# Time on batch: 42.51486921310425
# Working on batch #:  255
# lstm multi-margin loss on batch: 0.0022259356919676065
# Neural net cross-entropy loss on batch: 0.32714100853961525
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0018987946677953005
# Time on batch: 63.26059937477112
# Working on batch #:  256
# lstm multi-margin loss on batch: 0.007095364388078451
# Neural net cross-entropy loss on batch: 0.23420759872338276
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0068611567839980125
# Time on batch: 39.70357847213745
# Working on batch #:  257
# lstm multi-margin loss on batch: 0.0038705423939973116
# Neural net cross-entropy loss on batch: 0.31060133785297284
# Neural net accuracy on batch: 0.925
# Overall loss: 0.0035599409602582455
# Time on batch: 39.60023760795593
# Working on batch #:  258
# lstm multi-margin loss on batch: 0.004196845460683107
# Neural net cross-entropy loss on batch: 0.23193208876024834
# Neural net accuracy on batch: 0.975
# Overall loss: 0.003964913543313742
# Time on batch: 46.76616549491882
# Working on batch #:  259
# lstm multi-margin loss on batch: 0.005206335335969925
# Neural net cross-entropy loss on batch: 0.3435212858439936
# Neural net accuracy on batch: 0.9
# Overall loss: 0.004862814210355282
# Time on batch: 58.64042901992798
# Working on batch #:  260
# lstm multi-margin loss on batch: 0.003696917090564966
# Neural net cross-entropy loss on batch: 0.24873557699944052
# Neural net accuracy on batch: 0.95
# Overall loss: 0.003448181552812457
# Time on batch: 35.31912803649902
# Working on batch #:  261
# lstm multi-margin loss on batch: 0.005048867780715227
# Neural net cross-entropy loss on batch: 0.2739992823266788
# Neural net accuracy on batch: 0.925
# Overall loss: 0.004774868488311768
# Time on batch: 42.7590446472168
# Working on batch #:  262
# lstm multi-margin loss on batch: 0.00209173490293324
# Neural net cross-entropy loss on batch: 0.315008424066734
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0017767264507710934
# Time on batch: 37.264456033706665
# Working on batch #:  263
# lstm multi-margin loss on batch: 0.0028430200181901455
# Neural net cross-entropy loss on batch: 0.2831582745623612
# Neural net accuracy on batch: 0.95
# Overall loss: 0.00255986163392663
# Time on batch: 41.01044011116028
# Working on batch #:  264
# lstm multi-margin loss on batch: 0.002813381841406226
# Neural net cross-entropy loss on batch: 0.476445772371796
# Neural net accuracy on batch: 0.85
# Overall loss: 0.0023369360715150833
# Time on batch: 44.52601981163025
# Working on batch #:  265
# lstm multi-margin loss on batch: 0.006429505534470081
# Neural net cross-entropy loss on batch: 0.25124716724197116
# Neural net accuracy on batch: 0.925
# Overall loss: 0.006178258452564478
# Time on batch: 39.63020086288452
# Working on batch #:  266
# lstm multi-margin loss on batch: 0.005516085773706436
# Neural net cross-entropy loss on batch: 0.26726244389289683
# Neural net accuracy on batch: 0.925
# Overall loss: 0.005248823203146458
# Time on batch: 40.504703760147095
# Working on batch #:  267
# lstm multi-margin loss on batch: 0.003049298422411084
# Neural net cross-entropy loss on batch: 0.3042205904442917
# Neural net accuracy on batch: 0.975
# Overall loss: 0.002745077945291996
# Time on batch: 39.45165705680847
# Working on batch #:  268
# lstm multi-margin loss on batch: 0.0036917226389050484
# Neural net cross-entropy loss on batch: 0.2880645916742204
# Neural net accuracy on batch: 0.9
# Overall loss: 0.0034036580473184586
# Time on batch: 44.73369288444519
# Working on batch #:  269
# lstm multi-margin loss on batch: 0.005822294391691685
# Neural net cross-entropy loss on batch: 0.3666448904732439
# Neural net accuracy on batch: 0.85
# Overall loss: 0.005455649457871914
# Time on batch: 34.25211548805237
# Working on batch #:  270
# lstm multi-margin loss on batch: 0.0033292046282440424
# Neural net cross-entropy loss on batch: 0.2758978992930807
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0030533066019415855
# Time on batch: 38.55674624443054
# Working on batch #:  271
# lstm multi-margin loss on batch: 0.010434683412313461
# Neural net cross-entropy loss on batch: 0.3690675180349893
# Neural net accuracy on batch: 0.85
# Overall loss: 0.010065616108477116
# Time on batch: 46.1214497089386
# Working on batch #:  272
# lstm multi-margin loss on batch: 0.002655769232660532
# Neural net cross-entropy loss on batch: 0.3155958653535149
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0023401733487844467
# Time on batch: 37.74280333518982
# Working on batch #:  273
# lstm multi-margin loss on batch: 0.005822832230478525
# Neural net cross-entropy loss on batch: 0.46943774215098316
# Neural net accuracy on batch: 0.825
# Overall loss: 0.00535339443013072
# Time on batch: 38.694926738739014
# Working on batch #:  274
# lstm multi-margin loss on batch: 0.003936853725463152
# Neural net cross-entropy loss on batch: 0.41780912736581566
# Neural net accuracy on batch: 0.85
# Overall loss: 0.003519044490531087
# Time on batch: 39.6329619884491
# Working on batch #:  275
# lstm multi-margin loss on batch: 0.0016521799843758345
# Neural net cross-entropy loss on batch: 0.23653639494578488
# Neural net accuracy on batch: 0.875
# Overall loss: 0.0014156436081975698
# Time on batch: 56.92103552818298
# Working on batch #:  276
# lstm multi-margin loss on batch: 0.007529746741056442
# Neural net cross-entropy loss on batch: 0.2946058369140577
# Neural net accuracy on batch: 0.925
# Overall loss: 0.007235141005367041
# Time on batch: 39.78415107727051
# Working on batch #:  277
# lstm multi-margin loss on batch: 0.010878382250666618
# Neural net cross-entropy loss on batch: 0.24989965745776707
# Neural net accuracy on batch: 0.975
# Overall loss: 0.010628482326865196
# Time on batch: 69.30140590667725
# Working on batch #:  278
# lstm multi-margin loss on batch: 0.004672876093536615
# Neural net cross-entropy loss on batch: 0.24850146091340647
# Neural net accuracy on batch: 0.925
# Overall loss: 0.004424374550580978
# Time on batch: 38.654236793518066
# Working on batch #:  279
# lstm multi-margin loss on batch: 0.005628347396850586
# Neural net cross-entropy loss on batch: 0.2690772844113407
# Neural net accuracy on batch: 0.95
# Overall loss: 0.005359270144253969
# Time on batch: 46.36219310760498
# Working on batch #:  280
# lstm multi-margin loss on batch: 0.010776855051517487
# Neural net cross-entropy loss on batch: 0.2688154735467534
# Neural net accuracy on batch: 0.9
# Overall loss: 0.010508039966225624
# Time on batch: 38.24389886856079
# Working on batch #:  281
# lstm multi-margin loss on batch: 0.003541105892509222
# Neural net cross-entropy loss on batch: 0.24348614770932006
# Neural net accuracy on batch: 0.95
# Overall loss: 0.003297619754448533
# Time on batch: 40.36600375175476
# Working on batch #:  282
# lstm multi-margin loss on batch: 0.004042451269924641
# Neural net cross-entropy loss on batch: 0.3906447211255154
# Neural net accuracy on batch: 0.825
# Overall loss: 0.0036518066190183163
# Time on batch: 33.9694561958313
# Working on batch #:  283
# lstm multi-margin loss on batch: 0.006821949500590563
# Neural net cross-entropy loss on batch: 0.32286269733774786
# Neural net accuracy on batch: 0.925
# Overall loss: 0.00649908697232604
# Time on batch: 41.35263419151306
# Working on batch #:  284
# lstm multi-margin loss on batch: 0.008042589761316776
# Neural net cross-entropy loss on batch: 0.26307909526237366
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0077795106917619705
# Time on batch: 35.682077169418335
# Working on batch #:  285
# lstm multi-margin loss on batch: 0.0038158120587468147
# Neural net cross-entropy loss on batch: 0.2483315788613214
# Neural net accuracy on batch: 0.925
# Overall loss: 0.003567480482161045
# Time on batch: 33.40886616706848
# Working on batch #:  286
# lstm multi-margin loss on batch: 0.0055982014164328575
# Neural net cross-entropy loss on batch: 0.2409714977526586
# Neural net accuracy on batch: 0.95
# Overall loss: 0.005357230082154274
# Time on batch: 51.463231801986694
# Working on batch #:  287
# lstm multi-margin loss on batch: 0.0039526354521512985
# Neural net cross-entropy loss on batch: 0.26665372241602114
# Neural net accuracy on batch: 0.9
# Overall loss: 0.003685981733724475
# Time on batch: 37.650655031204224
# Working on batch #:  288
# lstm multi-margin loss on batch: 0.005193471908569336
# Neural net cross-entropy loss on batch: 0.3124221751301751
# Neural net accuracy on batch: 0.85
# Overall loss: 0.004881049506366253
# Time on batch: 40.20147705078125
# Working on batch #:  289
# lstm multi-margin loss on batch: 0.003371705999597907
# Neural net cross-entropy loss on batch: 0.3600774112007002
# Neural net accuracy on batch: 0.875
# Overall loss: 0.003011628519743681
# Time on batch: 39.813878297805786
# Working on batch #:  290
# lstm multi-margin loss on batch: 0.0069824038073420525
# Neural net cross-entropy loss on batch: 0.2764530514216049
# Neural net accuracy on batch: 0.9
# Overall loss: 0.006705950945615768
# Time on batch: 40.80535364151001
# Working on batch #:  291
# lstm multi-margin loss on batch: 0.003052615560591221
# Neural net cross-entropy loss on batch: 0.22168758069324018
# Neural net accuracy on batch: 0.95
# Overall loss: 0.0028309279587119818
# Time on batch: 34.71698975563049
# Working on batch #:  292
# lstm multi-margin loss on batch: 0.0022593641187995672
# Neural net cross-entropy loss on batch: 0.22819428017179044
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002031169831752777
# Time on batch: 215.65681767463684
# Working on batch #:  293
# lstm multi-margin loss on batch: 0.004609536845237017
# Neural net cross-entropy loss on batch: 0.3296914007698221
# Neural net accuracy on batch: 0.9
# Overall loss: 0.004279845394194126
# Time on batch: 42.00794792175293
# Working on batch #:  294
# lstm multi-margin loss on batch: 0.005021871067583561
# Neural net cross-entropy loss on batch: 0.27956952867039275
# Neural net accuracy on batch: 0.9
# Overall loss: 0.004742301534861326
# Time on batch: 38.79759669303894
# Working on batch #:  295
# lstm multi-margin loss on batch: 0.002471059560775757
# Neural net cross-entropy loss on batch: 0.5618176543741487
# Neural net accuracy on batch: 0.8
# Overall loss: 0.0019092418951913714
# Time on batch: 44.98939824104309
# Working on batch #:  296
# lstm multi-margin loss on batch: 0.0038643497973680496
# Neural net cross-entropy loss on batch: 0.31986574333718243
# Neural net accuracy on batch: 0.9
# Overall loss: 0.003544484032317996
# Time on batch: 35.27121615409851
# Working on batch #:  297
# lstm multi-margin loss on batch: 0.005482434295117855
# Neural net cross-entropy loss on batch: 0.2727783609235818
# Neural net accuracy on batch: 0.9
# Overall loss: 0.005209655966609716
# Time on batch: 35.80185270309448
# Working on batch #:  298
# lstm multi-margin loss on batch: 0.0036661780904978514
# Neural net cross-entropy loss on batch: 0.37007363700593865
# Neural net accuracy on batch: 0.8
# Overall loss: 0.0032961044926196337
# Time on batch: 39.26544404029846
# Working on batch #:  299
# lstm multi-margin loss on batch: 0.0028950136620551348
# Neural net cross-entropy loss on batch: 0.38618048992700305
# Neural net accuracy on batch: 0.8
# Overall loss: 0.002508833073079586
# Time on batch: 38.77048850059509
# Working on batch #:  300
# lstm multi-margin loss on batch: 0.0009550265385769308
# Neural net cross-entropy loss on batch: 0.5036878107193916
# Neural net accuracy on batch: 0.8
# Overall loss: 0.00045133871026337147
# Time on batch: 35.122939348220825
# 119685
# 0 2394 4788 7182 9576 11970 14364 16758 19152 21546 23940 26334 28728 31122 33516 35910 38304 40698 43092 45486 47880 50274 52668 55062 57456 59850 62244 64638 67032 69426 71820 74214 76608 79002 81396 83790 86184 88578 90972 93366 95760 98154 100548 102942 105336 107730 110124 112518 114912 117306 Test AUC score: 0.690906629703
# Working on batch #:  302
# lstm multi-margin loss on batch: 0.00134953111410141
# Neural net cross-entropy loss on batch: 0.2522089493028925
# Neural net accuracy on batch: 0.925
# Overall loss: 0.0010973222088068724
# Time on batch: 40.34195923805237
# Working on batch #:  303
# lstm multi-margin loss on batch: 0.00302652339451015
# Neural net cross-entropy loss on batch: 0.29187298019505215
# Neural net accuracy on batch: 0.9
# Overall loss: 0.002734650392085314
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-87080bc8da9d> in <module>()
#      86         overall_loss = loss_batch_similarity - (lamb * loss_batch_domain_classification)
#      87         print('Overall loss: ' + str(overall_loss.data[0]))
# ---> 88         overall_loss.backward()
#      89         optimizer_lstm.step()
#      90         optimizer_nn.step()
#
# ~\Anaconda3\envs\py35\lib\site-packages\torch\autograd\variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     154                 Variable.
#     155         """
# --> 156         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     157
#     158     def register_hook(self, hook):
#
# ~\Anaconda3\envs\py35\lib\site-packages\torch\autograd\__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %%
''' Encoder (LSTM) '''
#lstm_x = torch.load('../Pickle/lstm_domain_adapt_title_body_e2_b50.pt')

''' Procedural parameters '''
auc_scorer = AUCMeter()

# Evaluate on dev set for AUC score
test_AUC_score = eval_model(lstm, test_question_ids_android, test_data_android, word2vec, android_id_to_data_title, android_id_to_data_body,
                            word_to_id_vocab, truncation_val_title, truncation_val_body)

print("Test AUC score:", test_AUC_score)
# Out:
# 119786
# 0 2396 4792 7188 9584 11980 14376 16772 19168 21564 23960 26356 28752 31148 33544 35940 38336 40732 43128 45524 47920 50316 52712 55108 57504 59900 62296 64692 67088 69484 71880 74276 76672 79068 81464 83860 86256 88652 91048 93444 95840 98236 100632 103028 105424 107820 110216 112612 115008 117404 Test AUC score: 0.689754596694
